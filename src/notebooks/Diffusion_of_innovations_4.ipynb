# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/200 runs.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 200
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
results = (experiments, outcomes)
from analysis.plotting import envelopes, KDE, lines
for key, value in outcomes.items():
     if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
#         n = key
#         plt.savefig("./pictures/KDE {}.png".format(key), dpi=75)
    
plt.show()
# Out:
# [INFO/MainProcess] no time dimension found in results
# [INFO/MainProcess] no time dimension found in results
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-025d5d43df16> in <module>()
#       5         fig, axes = lines(results, outcomes_to_show=key, density=KDE,
#       6                       show_envelope=True, experiments_to_show=indices,
# ----> 7                       titles="")
#       8 #         n = key
#       9 #         plt.savefig("./pictures/KDE {}.png".format(key), dpi=75)
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\plotting.pyc in lines(results, outcomes_to_show, group_by, grouping_specifiers, density, titles, ylabels, legend, experiments_to_show, show_envelope, log)
#     293                                 grouping_specifiers=grouping_specifiers,
#     294                                 experiments_to_show=experiments_to_show,
# --> 295                                 titles=titles, ylabels=ylabels, log=log)
#     296
#     297     if experiments_to_show != None:
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\plotting.pyc in plot_lines_with_envelopes(results, outcomes_to_show, group_by, grouping_specifiers, density, titles, ylabels, legend, experiments_to_show, log)
#     442         else:
#     443             value = full_outcomes[outcome_to_plot]
# --> 444             plot_envelope(ax, 0, time, value, fill=True)
#     445             if density:
#     446                 simple_density(density, value, ax_d, ax, log)
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.pyc in plot_envelope(ax, j, time, value, fill)
#     111                         maximum,
#     112                         facecolor=color,
# --> 113                         alpha=0.3,
#     114                         )
#     115     else:
#
# C:\Anaconda\lib\site-packages\matplotlib\axes.pyc in fill_between(self, x, y1, y2, where, interpolate, **kwargs)
#    6986
#    6987         # Convert the arrays so we can work with them
# -> 6988         x = ma.masked_invalid(self.convert_xunits(x))
#    6989         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    6990         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# C:\Anaconda\lib\site-packages\numpy\ma\core.pyc in masked_invalid(a, copy)
#    2242         cls = type(a)
#    2243     else:
# -> 2244         condition = ~(np.isfinite(a))
#    2245         cls = MaskedArray
#    2246     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
# # ooi = outcomes[ooi_name]
# # ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
# # temp_outcomes = {ooi_name: ooi}
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# # print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 88.8

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
        data = data[ooi]
        data = data[:,-1]
        classes = np.zeros(data.shape)
        classes[data>25] = 1
        return classes
    
prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 250 points remaining, containing 31 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.052, coverage: 0.41935483871, density: 1.0 restricted_dimensions: 10.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density   mass      mean  res dim
# 0   1.000000  0.124000  1.000  0.124000        0
# 1   1.000000  0.130802  0.948  0.130802        1
# 2   1.000000  0.137778  0.900  0.137778        1
# 3   1.000000  0.145540  0.852  0.145540        1
# 4   1.000000  0.153465  0.808  0.153465        2
# 5   1.000000  0.162304  0.764  0.162304        3
# 6   1.000000  0.171271  0.724  0.171271        4
# 7   1.000000  0.181287  0.684  0.181287        4
# 8   1.000000  0.191358  0.648  0.191358        5
# 9   1.000000  0.202614  0.612  0.202614        5
# 10  1.000000  0.213793  0.580  0.213793        5
# 11  1.000000  0.226277  0.548  0.226277        5
# 12  1.000000  0.238462  0.520  0.238462        5
# 13  1.000000  0.252033  0.492  0.252033        5
# 14  1.000000  0.267241  0.464  0.267241        5
# 15  1.000000  0.281818  0.440  0.281818        5
# 16  1.000000  0.298077  0.416  0.298077        5
# 17  1.000000  0.316327  0.392  0.316327        6
# 18  1.000000  0.333333  0.372  0.333333        6
# 19  1.000000  0.352273  0.352  0.352273        6
# 20  1.000000  0.373494  0.332  0.373494        6
# 21  1.000000  0.397436  0.312  0.397436        7
# 22  1.000000  0.418919  0.296  0.418919        8
# 23  1.000000  0.442857  0.280  0.442857        9
# 24  1.000000  0.469697  0.264  0.469697       10
# 25  1.000000  0.500000  0.248  0.500000       10
# 26  1.000000  0.534483  0.232  0.534483       10
# 27  1.000000  0.563636  0.220  0.563636       10
# 28  1.000000  0.596154  0.208  0.596154       10
# 29  1.000000  0.632653  0.196  0.632653       10
# 30  1.000000  0.673913  0.184  0.673913       10
# 31  1.000000  0.688889  0.180  0.688889       10
# 32  0.935484  0.743590  0.156  0.743590       10
# 33  0.935484  0.783784  0.148  0.783784       10
# 34  0.935484  0.828571  0.140  0.828571       10
# 35  0.903226  0.848485  0.132  0.848485       10
# 36  0.903226  0.875000  0.128  0.875000       10
# 37  0.870968  0.900000  0.120  0.900000       10
# 38  0.838710  0.928571  0.112  0.928571       10
# 39  0.806452  0.961538  0.104  0.961538       10
# 40  0.774194  1.000000  0.096  1.000000       10
# 41  0.709677  1.000000  0.088  1.000000       10
# 42  0.645161  1.000000  0.080  1.000000       10
# 43  0.612903  1.000000  0.076  1.000000       10
# 44  0.580645  1.000000  0.072  1.000000       10
# 45  0.548387  1.000000  0.068  1.000000       10
# 46  0.516129  1.000000  0.064  1.000000       10
# 47  0.483871  1.000000  0.060  1.000000       10
# 48  0.451613  1.000000  0.056  1.000000       10
# 49  0.419355  1.000000  0.052  1.000000       10

# %%
box1.inspect(34)
box1.inspect(37)
box1.inspect(39)
# Out:
# box        mean      mass  coverage   density   res dim
# 34         0.83      0.14      0.94      0.83        10
#
# uncertainty                                              box 34
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     1.32e-04
# learning_rate_adoption                                 0.90 -    0.94     4.62e-04
# Increase_in_memory_for_late_categories                    2 -      17     3.33e-02
# change_threshold_to_reach_for_weights_2                0.52 -    0.77     5.13e-02
# A_S_L_preferred_information_source_laggard_4           0.11 -    0.29     1.15e-01
# Interaction_3_multiplicator                            0.59 -    1.45     2.44e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.20     2.44e-01
# A_S_L_preferred_information_source_early_majority_3    0.28 -    0.54     3.43e-01
# A_S_L_preferred_information_source_late_majority_2     0.00 -    0.10     3.43e-01
# A_S_L_preferred_information_source_laggard_3           0.00 -    0.19     6.07e-01
#
#
# box        mean      mass  coverage   density   res dim
# 37          0.9      0.12      0.87       0.9        10
#
# uncertainty                                              box 37
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     4.31e-05
# learning_rate_adoption                                 0.90 -    0.94     1.15e-04
# Increase_in_memory_for_late_categories                    3 -      17     6.99e-03
# change_threshold_to_reach_for_weights_2                0.52 -    0.77     6.39e-02
# A_S_L_preferred_information_source_laggard_4           0.11 -    0.29     1.08e-01
# A_S_L_preferred_information_source_early_majority_3    0.30 -    0.54     1.23e-01
# Interaction_3_multiplicator                            0.59 -    1.45     1.79e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.20     1.79e-01
# A_S_L_preferred_information_source_late_majority_2     0.00 -    0.10     2.89e-01
# A_S_L_preferred_information_source_laggard_3           0.00 -    0.19     6.47e-01
#
#
# box        mean      mass  coverage   density   res dim
# 39         0.96       0.1      0.81      0.96        10
#
# uncertainty                                              box 39
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     4.58e-05
# learning_rate_adoption                                 0.90 -    0.94     1.48e-04
# Increase_in_memory_for_late_categories                    3 -      17     1.63e-02
# A_S_L_preferred_information_source_early_majority_3    0.33 -    0.54     3.17e-02
# change_threshold_to_reach_for_weights_2                0.52 -    0.77     5.42e-02
# A_S_L_preferred_information_source_early_majority_1    0.02 -    0.20     6.20e-02
# Interaction_3_multiplicator                            0.59 -    1.45     1.09e-01
# A_S_L_preferred_information_source_laggard_4           0.11 -    0.29     2.16e-01
# A_S_L_preferred_information_source_late_majority_2     0.00 -    0.10     4.16e-01
# A_S_L_preferred_information_source_laggard_3           0.00 -    0.19     7.36e-01

# %%
prim_obj.show_boxes()
plt.show()
