# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2000 runs experiment 3.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 150
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines

results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 75.85

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<8] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 2000 points remaining, containing 727 cases of interest
# [INFO/MainProcess] mean: 0.975, mass: 0.06, coverage: 0.160935350757, density: 0.975 restricted_dimensions: 19

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density    mass       mean res dim
# 0           1     0.2425       1     0.2425       0
# 1           1  0.2552632    0.95  0.2552632       1
# 2           1  0.2686981  0.9025  0.2686981       1
# 3           1  0.2829638   0.857  0.2829638       1
# 4           1  0.2979115   0.814  0.2979115       1
# 5   0.9979381   0.313066   0.773   0.313066       1
# 6   0.9979381  0.3297003   0.734  0.3297003       1
# 7   0.9896907  0.3443329   0.697  0.3443329       1
# 8   0.9731959  0.3630769    0.65  0.3630769       2
# 9   0.9608247  0.3773279  0.6175  0.3773279       2
# 10  0.9587629  0.3964194  0.5865  0.3964194       2
# 11   0.942268  0.4102334   0.557  0.4102334       2
# 12  0.9175258  0.4262452   0.522  0.4262452       2
# 13  0.8969072   0.453125    0.48   0.453125       2
# 14  0.8618557  0.4744608  0.4405  0.4744608       2
# 15  0.8412371  0.5093633  0.4005  0.5093633       2
# 16  0.8206186  0.5236842    0.38  0.5236842       2
# 17  0.7814433  0.5500726  0.3445  0.5500726       2
# 18  0.7463918     0.5792  0.3125     0.5792       2
# 19  0.7298969  0.5969646  0.2965  0.5969646       3
# 20  0.6907216      0.625   0.268      0.625       4
# 21  0.6659794   0.640873   0.252   0.640873       4
# 22   0.643299  0.6666667   0.234  0.6666667       4
# 23  0.6206186  0.6779279   0.222  0.6779279       4
# 24        0.6  0.6912114  0.2105  0.6912114       4
# 25   0.585567  0.7117794  0.1995  0.7117794       4
# 26  0.5649485  0.7229551  0.1895  0.7229551       5
# 27  0.5463918  0.7361111    0.18  0.7361111       5
# 28  0.5278351   0.748538   0.171   0.748538       6
# 29  0.5072165  0.7616099  0.1615  0.7616099       6
# 30   0.428866  0.8093385  0.1285  0.8093385       7
# 31  0.4123711  0.8196721   0.122  0.8196721       8
# 32  0.3938144  0.8304348   0.115  0.8304348       8
# 33  0.3134021  0.8735632   0.087  0.8735632       8
# 34  0.3010309  0.8848485  0.0825  0.8848485       8
# 35  0.2886598  0.8974359   0.078  0.8974359       9
# 36  0.2783505  0.9121622   0.074  0.9121622      10
# 37  0.2742268  0.9172414  0.0725  0.9172414      11
# 38  0.2618557  0.9270073  0.0685  0.9270073      12
# 39  0.2515464  0.9384615   0.065  0.9384615      13
# 40  0.2412371  0.9512195  0.0615  0.9512195      14
# 41  0.2309278  0.9655172   0.058  0.9655172      15
# 42  0.2206186  0.9727273   0.055  0.9727273      15
# 43  0.2123711  0.9809524  0.0525  0.9809524      15
# 44   0.214433  0.9811321   0.053  0.9811321      15
# 45  0.2164948  0.9813084  0.0535  0.9813084      15
# 46  0.2185567  0.9814815   0.054  0.9814815      15
# 47  0.2206186  0.9816514  0.0545  0.9816514      15
# 48  0.2226804  0.9818182   0.055  0.9818182      15
# 49  0.2247423   0.981982  0.0555   0.981982      15
#
# [50 rows x 5 columns]

# %%
box1.inspect(16)
box1.inspect(21)
box1.inspect(30)
# Out:
# box        mean      mass  coverage   density   res dim
# 16         0.65      0.34      0.61      0.65         3
#
# uncertainty                                                       box 16
#                                                                  min       max    qp values
# growth_phase                                                      19 -      36     5.25e-20
# memory                                                             1 -       3     6.37e-13
# variation_of_SD_normal_distribution_properties_of_households    0.50 -    1.45     2.90e-01
#
#
# box        mean      mass  coverage   density   res dim
# 21         0.71      0.26       0.5      0.71         7
#
# uncertainty                                                       box 21
#                                                                  min       max    qp values
# growth_phase                                                      20 -      36     3.79e-20
# memory                                                             1 -       3     3.98e-14
# electricity_price_offpeak_fix                                   0.15 -    0.29     2.10e-01
# change_threshold_to_reach_for_weights_3                         0.58 -    2.00     2.13e-01
# Multiplication_SD_minimum_amount_of_savings                     0.69 -    4.00     2.81e-01
# variation_of_SD_normal_distribution_properties_of_households    0.50 -    1.45     3.09e-01
# change_threshold_to_reach_for_weights_5                         0.57 -    2.00     3.16e-01
#
#
# box        mean      mass  coverage   density   res dim
# 30         0.81      0.16      0.35      0.81        11
#
# uncertainty                                                       box 30
#                                                                  min       max    qp values
# growth_phase                                                      23 -      36     9.67e-24
# memory                                                             1 -       3     2.98e-13
# Multiplication_SD_minimum_amount_of_savings                     0.69 -    3.82     6.74e-02
# change_threshold_to_reach_for_weights_3                         0.58 -    2.00     1.36e-01
# change_threshold_to_reach_for_weights_5                         0.64 -    2.00     1.77e-01
# electricity_price_offpeak_fix                                   0.15 -    0.29     1.78e-01
# Initial_minimum_amount_savings_bounded_rational                 1.00 -    3.84     2.46e-01
# Interaction_3_multiplicator                                     0.50 -    1.46     2.54e-01
# A_S_L_preferred_information_source_early_adopter_1              0.26 -    0.55     3.07e-01
# Interaction_1_multiplicator                                     0.55 -    1.50     3.35e-01
# variation_of_SD_normal_distribution_properties_of_households    0.50 -    1.45     3.65e-01

# %%
prim_obj.show_boxes()
plt.show()
