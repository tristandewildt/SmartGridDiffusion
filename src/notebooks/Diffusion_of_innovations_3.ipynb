# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/1000 runs experiment 4.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 150
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines

results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 75.85

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<50] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 461 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.064, coverage: 0.138828633406, density: 1.0 restricted_dimensions: 5

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density   mass       mean res dim
# 0           1      0.461      1      0.461       0
# 1    0.978308  0.4747368   0.95  0.4747368       1
# 2   0.9652928  0.4933481  0.902  0.4933481       1
# 3   0.9436009  0.5081776  0.856  0.5081776       1
# 4   0.9175705  0.5202952  0.813  0.5202952       1
# 5   0.9088937  0.5427461  0.772  0.5427461       1
# 6   0.8937093  0.5620737  0.733  0.5620737       1
# 7   0.8785249  0.5818966  0.696  0.5818966       1
# 8   0.8611714  0.6006051  0.661  0.6006051       1
# 9    0.845987  0.6220096  0.627  0.6220096       1
# 10  0.8286334  0.6420168  0.595  0.6420168       1
# 11  0.8112798  0.6619469  0.565  0.6619469       1
# 12  0.7982646  0.6865672  0.536  0.6865672       1
# 13  0.7852495  0.7111984  0.509  0.7111984       1
# 14  0.7678959  0.7329193  0.483  0.7329193       1
# 15  0.7483731  0.7532751  0.458  0.7532751       1
# 16  0.7331887  0.7770115  0.435  0.7770115       1
# 17  0.7093275  0.7917676  0.413  0.7917676       1
# 18   0.691974  0.8137755  0.392  0.8137755       1
# 19   0.670282  0.8306452  0.372  0.8306452       2
# 20    0.64859  0.8470255  0.353  0.8470255       2
# 21  0.6312364  0.8686567  0.335  0.8686567       2
# 22  0.6117137  0.8867925  0.318  0.8867925       2
# 23  0.5921909  0.9039735  0.302  0.9039735       2
# 24  0.5683297  0.9160839  0.286  0.9160839       2
# 25  0.5444685  0.9261993  0.271  0.9261993       2
# 26  0.5227766  0.9377432  0.257  0.9377432       2
# 27  0.5010846  0.9467213  0.244  0.9467213       2
# 28  0.4815618   0.961039  0.231   0.961039       2
# 29  0.4598698  0.9680365  0.219  0.9680365       2
# 30  0.4403471  0.9759615  0.208  0.9759615       3
# 31  0.4208243   0.979798  0.198   0.979798       4
# 32  0.4013015  0.9840426  0.188  0.9840426       4
# 33  0.3817787   0.988764  0.178   0.988764       4
# 34  0.3644252  0.9940828  0.169  0.9940828       5
# 35  0.2798265          1  0.129          1       6
# 36  0.2646421          1  0.122          1       6
# 37  0.2494577          1  0.115          1       6
# 38  0.2364425          1  0.109          1       6
# 39  0.2234273          1  0.103          1       6
# 40  0.2104121          1  0.097          1       6
# 41  0.1995662          1  0.092          1       6
# 42  0.1887202          1  0.087          1       6
# 43  0.1778742          1  0.082          1       6
# 44  0.1670282          1  0.077          1       6
# 45  0.1583514          1  0.073          1       6
# 46  0.1496746          1  0.069          1       6
# 47  0.1409978          1  0.065          1       6
# 48   0.132321          1  0.061          1       6
# 49  0.1236443          1  0.057          1       6
# 50  0.1171367          1  0.054          1       6
# 51  0.1106291          1  0.051          1       6
# 52  0.1388286          1  0.064          1       5
#
# [53 rows x 5 columns]

# %%
box1.inspect(12)
box1.inspect(15)
box1.inspect(18)
# Out:
# box        mean      mass  coverage   density   res dim
# 12         0.69      0.54       0.8      0.69         1
#
# uncertainty                     box 12
#                                min       max    qp values
# Learning_rate_appliances_1    0.96 -    0.98     4.78e-26
#
#
# box        mean      mass  coverage   density   res dim
# 15         0.75      0.46      0.75      0.75         1
#
# uncertainty                     box 15
#                                min       max    qp values
# Learning_rate_appliances_1    0.96 -    0.98     3.58e-37
#
#
# box        mean      mass  coverage   density   res dim
# 18         0.81      0.39      0.69      0.81         1
#
# uncertainty                     box 18
#                                min       max    qp values
# Learning_rate_appliances_1    0.96 -    0.98     5.89e-47

# %%
prim_obj.show_boxes()
plt.show()
