# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import Series, DataFrame, Index

# %%
df = pd.read_csv(r'./netlogo_models/Model_adoption_of_ISG_appliances_-_5.9.3_for_EMA_temp_plot.csv',skiprows=5)

# %%
print (df)
# Out:
#    a_s_l_preferred_information_source_early_adopter_1  \
# 0                                                 0.4
# 1                                                 NaN
# 2                               "Plot for monitoring"
# 3                                               x min
# 4                                                   0
# 5                                                 NaN
# 6                                            pen name
# 7   "Total savings of one household with 1 househo...
# 8   "Total savings of one household with 2 househo...
# 9   "Total savings of one household with 3 househo...
# 10  "Total savings of one household with 4 househo...
# 11  "Total savings of one household with 5 househo...
# 12                                                NaN
# 13  "Total savings of one household with 1 househo...
# 14                                                  x
# 15                                                  0
# ...

# %%
print (df.iloc[
