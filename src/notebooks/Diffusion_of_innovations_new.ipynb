# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import matplotlib as mpl

# import mpld3

# from mpld3 import plugins

# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/500_runs_experiment_1.bz2')
results = (experiments, outcomes)

# %%
desired__nr_lines = 50
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes
#from analysis.plotting_util import KDE
from analysis.plotting import lines, KDE, envelopes

for key, value in outcomes.items():
     if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")
#         n = key
#         plt.savefig("./pictures/KDE {}.png".format(n), dpi=75)
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,75].ravel(), 25)
# Out:
# 100.0

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<3] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.6)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 500 points remaining, containing 420 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.052, coverage: 0.0619047619048, density: 1.0 restricted_dimensions: 11

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(5)
box1.inspect(6)
# Out:
# box        mean      mass  coverage   density   res dim
# 5          0.89      0.79      0.84      0.89         5
#
# uncertainty                                        box 5
#                                                  min       max    qp values
# Degree_of_correlation_with_previous_data        0.23 -    0.80     1.20e-01
# A_S_L_preferred_information_source_laggard_5    0.20 -    0.39     2.84e-01
# growth_phase                                       8 -      60     2.87e-01
# A_S_L_preferred_information_source_laggard_4    0.10 -    0.29     3.23e-01
# introduction_phase                                 8 -      60     3.33e-01
#
#
# box        mean      mass  coverage   density   res dim
# 6           0.9      0.76      0.82       0.9         5
#
# uncertainty                                        box 6
#                                                  min       max    qp values
# Degree_of_correlation_with_previous_data        0.23 -    0.80     1.34e-01
# introduction_phase                                10 -      60     2.10e-01
# growth_phase                                       8 -      60     2.74e-01
# A_S_L_preferred_information_source_laggard_5    0.20 -    0.39     3.04e-01
# A_S_L_preferred_information_source_laggard_4    0.10 -    0.29     3.10e-01

# %%
box1.inspect(box1._cur_box)
# Out:
# box        mean      mass  coverage   density   res dim
# 44            1     0.054      0.26         1        17
#
# uncertainty                                              box 44
#                                                         min       max    qp values
# memory                                                    2 -       4     5.95e-04
# introduction_phase                                        6 -      36     1.91e-03
# social_value_difference_to_mean                        0.40 -    0.95     6.11e-02
# A_S_L_preferred_information_source_early_majority_2    0.17 -    0.34     2.33e-01
# A_S_L_preferred_information_source_laggard_4           0.12 -    0.29     2.66e-01
# difference_between_peak_and_offpeak_price              0.13 -    0.17     4.36e-01
# Interaction_4_multiplicator                            0.59 -    1.50     4.36e-01
# valuation_per_household_encountered_late_majority      0.05 -    0.10     4.55e-01
# growth_phase                                             14 -      60     4.90e-01
# Increase_in_memory_for_late_categories                    1 -      18     7.49e-01
# Interaction_2_multiplicator                            0.50 -    1.37     7.49e-01
# Number_of_month_before_decision_rejection                13 -      60     7.49e-01
# Multiplication_SD_minimum_amount_of_savings            0.65 -    4.00     7.49e-01
# A_S_L_preferred_information_source_late_majority_4     0.13 -    0.30     7.73e-01
# Degree_of_correlation_with_previous_data               0.20 -    0.78     1.00e+00
# minimum_percentage_for_no_rejection                    0.03 -    0.19     1.00e+00
# A_S_L_preferred_information_source_early_majority_3    0.25 -    0.53     1.00e+00

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density   mass       mean res dim
# 0           1       0.21      1       0.21       0
# 1    0.952381       0.25    0.8       0.25       1
# 2   0.9428571  0.2625995  0.754  0.2625995       2
# 3   0.9333333  0.2776204  0.706  0.2776204       2
# 4   0.9238095  0.2895522   0.67  0.2895522       3
# 5   0.9047619  0.3015873   0.63  0.3015873       3
# 6   0.8857143  0.3163265  0.588  0.3163265       3
# 7   0.8761905  0.3345455   0.55  0.3345455       3
# 8   0.8666667   0.348659  0.522   0.348659       3
# 9   0.8571429  0.3688525  0.488  0.3688525       3
# 10   0.847619  0.3852814  0.462  0.3852814       3
# 11  0.8285714  0.4009217  0.434  0.4009217       3
# 12  0.8190476  0.4174757  0.412  0.4174757       4
# 13  0.7809524  0.4480874  0.366  0.4480874       5
# 14  0.7714286  0.4682081  0.346  0.4682081       6
# 15  0.7619048  0.4878049  0.328  0.4878049       7
# 16  0.7428571  0.5032258   0.31  0.5032258       7
# 17  0.7333333  0.5238095  0.294  0.5238095       8
# 18  0.7238095  0.5467626  0.278  0.5467626       9
# 19  0.7047619  0.5606061  0.264  0.5606061       9
# 20  0.6857143      0.576   0.25      0.576      10
# 21  0.6666667  0.5932203  0.236  0.5932203      11
# 22   0.647619  0.6071429  0.224  0.6071429      12
# 23  0.6285714  0.6226415  0.212  0.6226415      13
# 24  0.6190476   0.631068  0.206   0.631068      14
# 25  0.6095238       0.64    0.2       0.64      15
# 26  0.5142857  0.7012987  0.154  0.7012987      15
# 27  0.5047619  0.7260274  0.146  0.7260274      15
# 28  0.4857143  0.7391304  0.138  0.7391304      15
# 29  0.4666667  0.7538462   0.13  0.7538462      15
# 30   0.447619  0.7704918  0.122  0.7704918      15
# 31  0.4380952  0.8070175  0.114  0.8070175      15
# 32  0.4285714  0.8333333  0.108  0.8333333      16
# 33  0.4190476  0.8461538  0.104  0.8461538      16
# 34        0.4  0.8571429  0.098  0.8571429      16
# 35  0.3809524  0.8695652  0.092  0.8695652      16
# 36   0.352381   0.902439  0.082   0.902439      16
# 37  0.3428571  0.9473684  0.076  0.9473684      17
# 38  0.3333333  0.9722222  0.072  0.9722222      17
# 39  0.3238095          1  0.068          1      17
# 40  0.3047619          1  0.064          1      17
# 41  0.2857143          1   0.06          1      17
# 42  0.2666667          1  0.056          1      17
# 43   0.247619          1  0.052          1      17
# 44  0.2571429          1  0.054          1      17
#
# [45 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
