# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import matplotlib as mpl

# import mpld3

# from mpld3 import plugins

# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2000 runs.bz2')
results = (experiments, outcomes)

# %%
desired__nr_lines = 30
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes
#from analysis.plotting_util import KDE
from analysis.plotting import lines, KDE, envelopes

for key, value in outcomes.items():
     if key == 'percentage_of_early_majority_with_ISG_appliances':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")
        n = key
        plt.savefig("./pictures/KDE {}.png".format(n), dpi=75)
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_majority_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 32.55

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data>80] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 2000 points remaining, containing 917 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.0515, coverage: 0.112322791712, density: 1.0 restricted_dimensions: 5

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(15)
box1.inspect(16)
# Out:
# box        mean      mass  coverage   density   res dim
# 15          0.8      0.46      0.81       0.8         1
#
# uncertainty                     box 15
#                                min       max    qp values
# Learning_rate_appliances_1    0.93 -    0.96    2.77e-102
#
#
# box        mean      mass  coverage   density   res dim
# 16         0.83      0.41      0.75      0.83         2
#
# uncertainty                     box 16
#                                min       max    qp values
# Learning_rate_appliances_1    0.93 -    0.96     1.47e-98
# division_effect_media            6 -      13     1.31e-02

# %%
box1.inspect(box1._cur_box)
# Out:
# box        mean      mass  coverage   density   res dim
# 50            1     0.051      0.11         1         5
#
# uncertainty                                                   box 50
#                                                              min       max    qp values
# Learning_rate_appliances_1                                  0.93 -    0.94     2.85e-22
# division_effect_media                                          6 -      12     5.45e-05
# memory                                                         2 -       5     2.08e-01
# threshold_to_reach_for_weights_information_reliability_3    0.50 -    1.46     1.00e+00
# difference_between_day_and_night_price                      0.13 -    0.40     1.00e+00

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density    mass       mean res dim
# 0           1     0.4585       1     0.4585       0
# 1           1  0.4826316    0.95  0.4826316       1
# 2           1  0.5080332  0.9025  0.5080332       1
# 3           1  0.5350058   0.857  0.5350058       1
# 4           1  0.5632678   0.814  0.5632678       1
# 5           1  0.5931436   0.773  0.5931436       1
# 6   0.9923664   0.619891   0.734   0.619891       1
# 7   0.9792803  0.6441894   0.697  0.6441894       1
# 8   0.9607415  0.6654079   0.662  0.6654079       1
# 9   0.9422028  0.6873508  0.6285  0.6873508       1
# 10  0.9236641  0.7093802   0.597  0.7093802       1
# 11  0.9018539  0.7292769   0.567  0.7292769       1
# 12  0.8833152  0.7520891  0.5385  0.7520891       1
# 13  0.8593239  0.7702835  0.5115  0.7702835       1
# 14  0.8331516  0.7868177  0.4855  0.7868177       1
# 15  0.8069793   0.802603   0.461   0.802603       1
# 16  0.7480916  0.8335358  0.4115  0.8335358       2
# 17   0.693566  0.8857939   0.359  0.8857939       2
# 18  0.6717557  0.9032258   0.341  0.9032258       3
# 19  0.6521265  0.9242658  0.3235  0.9242658       3
# 20  0.6281352  0.9381107   0.307  0.9381107       3
# 21  0.6019629  0.9468268  0.2915  0.9468268       3
# 22  0.5757906   0.954792  0.2765   0.954792       3
# 23  0.5507088  0.9619048  0.2625  0.9619048       3
# 24   0.525627  0.9678715   0.249  0.9678715       4
# 25  0.4285714  0.9874372   0.199  0.9874372       5
# 26  0.4089422  0.9920635   0.189  0.9920635       5
# 27  0.3904035  0.9972145  0.1795  0.9972145       5
# 28  0.3718648          1  0.1705          1       5
# 29  0.3522356          1  0.1615          1       5
# 30  0.3336968          1   0.153          1       5
# 31  0.3162486          1   0.145          1       5
# 32  0.2998909          1  0.1375          1       5
# 33  0.2846238          1  0.1305          1       5
# 34  0.2693566          1  0.1235          1       5
# 35  0.2551799          1   0.117          1       5
# 36  0.2420938          1   0.111          1       5
# 37  0.2290076          1   0.105          1       5
# 38   0.217012          1  0.0995          1       5
# 39  0.2061069          1  0.0945          1       5
# 40  0.1952017          1  0.0895          1       5
# 41  0.1853871          1   0.085          1       5
# 42  0.1755725          1  0.0805          1       5
# 43  0.1657579          1   0.076          1       5
# 44  0.1570338          1   0.072          1       5
# 45  0.1483097          1   0.068          1       5
# 46  0.1406761          1  0.0645          1       5
# 47  0.1330425          1   0.061          1       5
# 48  0.1254089          1  0.0575          1       5
# 49  0.1188659          1  0.0545          1       5
# 50  0.1123228          1  0.0515          1       5
#
# [51 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
