# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/1000_runs_experiment_1.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 30
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN
results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'percentage_of_early_majority_with_ISG_appliances':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show ()

# %%
import scipy as sp
ooi = "percentage_of_early_majority_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 97.5

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data>5] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.6)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 56 cases of interest
# [INFO/MainProcess] mean: 0.666666666667, mass: 0.051, coverage: 0.607142857143, density: 0.666666666667 restricted_dimensions: 15

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(50)
# Out:
# box        mean      mass  coverage   density   res dim
# 50         0.63     0.054      0.61      0.63        14
#
# uncertainty                                                     box 50
#                                                                min       max    qp values
# difference_between_peak_and_offpeak_price                     0.12 -    0.20     4.07e-06
# Change_minimum_amount_savings_bounded_rational                1.00 -    2.11     1.66e-05
# Learning_rate_appliances_1                                    0.94 -    0.97     2.56e-04
# A_S_L_preferred_information_source_late_majority_3            0.17 -    0.43     7.27e-02
# A_S_L_preferred_information_source_early_adopter_1            0.26 -    0.53     1.17e-01
# Interaction_5_multiplicator                                   0.54 -    1.39     1.34e-01
# memory                                                           1 -       4     1.52e-01
# valuation_per_household_encountered_early_adopters            0.05 -    0.19     1.76e-01
# Interaction_4_multiplicator                                   0.62 -    1.50     2.57e-01
# Lifetime_ISG_appliance                                           8 -      15     2.57e-01
# A_S_L_preferred_information_source_early_adopter_2            0.16 -    0.45     3.07e-01
# variation_of_SD_normal_distribution_properties_of_adopters    0.50 -    1.46     3.07e-01
# change_threshold_to_reach_for_weights_2                       0.50 -    1.46     3.63e-01
# A_S_L_preferred_information_source_early_majority_1           0.01 -    0.20     3.63e-01

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage     density   mass        mean res dim
# 0           1       0.056      1       0.056       0
# 1           1  0.05894737   0.95  0.05894737       1
# 2           1  0.06208426  0.902  0.06208426       2
# 3           1  0.06542056  0.856  0.06542056       2
# 4           1  0.06888069  0.813  0.06888069       3
# 5           1  0.07253886  0.772  0.07253886       3
# 6           1  0.07639836  0.733  0.07639836       4
# 7           1  0.08045977  0.696  0.08045977       4
# 8           1  0.08472012  0.661  0.08472012       4
# 9           1  0.08931419  0.627  0.08931419       4
# 10          1  0.09411765  0.595  0.09411765       4
# 11          1  0.09911504  0.565  0.09911504       4
# 12          1   0.1044776  0.536   0.1044776       4
# 13          1   0.1100196  0.509   0.1100196       4
# 14          1    0.115942  0.483    0.115942       4
# 15          1   0.1222707  0.458   0.1222707       4
# 16          1   0.1287356  0.435   0.1287356       5
# 17  0.9821429   0.1331719  0.413   0.1331719       5
# 18  0.9642857   0.1421053   0.38   0.1421053       6
# 19  0.9642857   0.1495845  0.361   0.1495845       7
# 20  0.9464286   0.1549708  0.342   0.1549708       7
# 21  0.9464286   0.1635802  0.324   0.1635802       7
# 22  0.9464286   0.1726384  0.307   0.1726384       8
# 23  0.9285714   0.1786942  0.291   0.1786942       8
# 24  0.9285714   0.1884058  0.276   0.1884058       8
# 25  0.9285714   0.1984733  0.262   0.1984733       9
# 26  0.9107143   0.2056452  0.248   0.2056452       9
# 27  0.9107143   0.2170213  0.235   0.2170213       9
# 28  0.9107143   0.2286996  0.223   0.2286996       9
# 29  0.8928571   0.2369668  0.211   0.2369668       9
# 30  0.8928571        0.25    0.2        0.25      10
# 31  0.8928571   0.2631579   0.19   0.2631579      10
# 32  0.8928571   0.2777778   0.18   0.2777778      11
# 33      0.875   0.2865497  0.171   0.2865497      11
# 34  0.8571429   0.2962963  0.162   0.2962963      11
# 35  0.8392857   0.3071895  0.153   0.3071895      11
# 36  0.8392857   0.3241379  0.145   0.3241379      11
# 37  0.8214286   0.3357664  0.137   0.3357664      11
# 38  0.8214286   0.3538462   0.13   0.3538462      11
# 39  0.8214286   0.3739837  0.123   0.3739837      12
# 40  0.8035714    0.387931  0.116    0.387931      12
# 41  0.8035714   0.4090909   0.11   0.4090909      12
# 42  0.7857143   0.4230769  0.104   0.4230769      12
# 43  0.7678571   0.4387755  0.098   0.4387755      12
# 44       0.75   0.4516129  0.093   0.4516129      12
# 45  0.7321429   0.4659091  0.088   0.4659091      12
# 46  0.7142857   0.4819277  0.083   0.4819277      12
# 47  0.6964286         0.5  0.078         0.5      12
# 48  0.6964286    0.527027  0.074    0.527027      13
# 49  0.6071429   0.5964912  0.057   0.5964912      14
# 50  0.6071429   0.6296296  0.054   0.6296296      14
# 51  0.6071429   0.6666667  0.051   0.6666667      15
#
# [52 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
