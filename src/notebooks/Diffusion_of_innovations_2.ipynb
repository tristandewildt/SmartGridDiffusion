# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2500_runs_experiment_2.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 50
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN
results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'new_households_with_ISG_appliance_stat':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show ()

# %%
import scipy as sp
ooi = "new_households_with_ISG_appliance_stat"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 96.9

# %%
ooi = "new_households_with_ISG_appliance_stat"
def classify(data):
    data = data[ooi]
    data = data[:,40]
    classes = np.zeros(data.shape)
    classes[data>20] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.6)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 2500 points remaining, containing 263 cases of interest
# [INFO/MainProcess] mean: 0.664122137405, mass: 0.0524, coverage: 0.330798479087, density: 0.664122137405 restricted_dimensions: 24

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(4)
box1.inspect(5)
# Out:
# box        mean      mass  coverage   density   res dim
# 4          0.14      0.72      0.97      0.14         2
#
# uncertainty               box 4
#                         min     max    qp values
# introduction_phase        6 -    30     2.96e-04
# division_effect_media     6 -    13     7.79e-02
#
#
# box        mean      mass  coverage   density   res dim
# 5          0.16      0.63      0.95      0.16         2
#
# uncertainty               box 5
#                         min     max    qp values
# introduction_phase        6 -    30     2.92e-04
# division_effect_media     6 -    12     8.14e-04

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density    mass       mean res dim
# 0           1     0.1052       1     0.1052       0
# 1           1  0.1124412  0.9356  0.1124412       1
# 2           1  0.1208085  0.8708  0.1208085       1
# 3           1  0.1304563  0.8064  0.1304563       1
# 4    0.973384  0.1419856  0.7212  0.1419856       2
# 5   0.9467681  0.1581957  0.6296  0.1581957       2
# 6   0.9277567  0.1695622  0.5756  0.1695622       2
# 7   0.9087452  0.1823036  0.5244  0.1823036       2
# 8   0.9011407  0.1903614   0.498  0.1903614       2
# 9   0.8897338  0.1979695  0.4728  0.1979695       2
# 10  0.8745247  0.2049911  0.4488  0.2049911       3
# 11  0.7794677  0.2308559  0.3552  0.2308559       4
# 12  0.7642586  0.2384342  0.3372  0.2384342       5
# 13  0.7110266  0.2575758  0.2904  0.2575758       5
# 14  0.6692015  0.2933333    0.24  0.2933333       5
# 15  0.6577947  0.3029772  0.2284  0.3029772       6
# 16  0.6463878  0.3136531  0.2168  0.3136531       7
# 17  0.6311787  0.3229572  0.2056  0.3229572       8
# 18  0.6159696  0.3319672  0.1952  0.3319672       9
# 19  0.6007605  0.3412527  0.1852  0.3412527      10
# 20  0.5855513  0.3507973  0.1756  0.3507973      11
# 21  0.5665399  0.3660934  0.1628  0.3660934      12
# 22  0.5551331   0.374359   0.156   0.374359      13
# 23   0.539924  0.3837838   0.148  0.3837838      14
# 24  0.5285171  0.3960114  0.1404  0.3960114      15
# 25   0.513308  0.4054054  0.1332  0.4054054      16
# 26  0.4828897  0.4233333    0.12  0.4233333      16
# 27  0.4714829  0.4350877   0.114  0.4350877      17
# 28  0.4486692  0.4503817  0.1048  0.4503817      17
# 29  0.4372624  0.4637097  0.0992  0.4637097      17
# 30  0.4258555  0.4765957   0.094  0.4765957      18
# 31  0.4144487  0.4887892  0.0892  0.4887892      19
# 32  0.4068441        0.5  0.0856        0.5      19
# 33  0.3992395  0.5172414  0.0812  0.5172414      20
# 34  0.3954373  0.5226131  0.0796  0.5226131      20
# 35  0.3840304  0.5343915  0.0756  0.5343915      20
# 36  0.3726236   0.547486  0.0716   0.547486      20
# 37   0.365019  0.5647059   0.068  0.5647059      21
# 38  0.3536122  0.5776398  0.0644  0.5776398      21
# 39  0.3269962  0.6099291  0.0564  0.6099291      22
# 40  0.3193916  0.6315789  0.0532  0.6315789      23
# 41  0.3117871  0.6507937  0.0504  0.6507937      24
# 42  0.3155894  0.6535433  0.0508  0.6535433      24
# 43  0.3193916    0.65625  0.0512    0.65625      24
# 44  0.3231939  0.6589147  0.0516  0.6589147      24
# 45  0.3269962  0.6615385   0.052  0.6615385      24
# 46  0.3307985  0.6641221  0.0524  0.6641221      24
#
# [47 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
