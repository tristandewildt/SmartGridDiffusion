# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/1000_runs_experiment_2.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 50
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN
results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'new_households_with_ISG_appliance_stat':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show ()

# %%
import scipy as sp
ooi = "new_households_with_ISG_appliance_stat"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 99.5

# %%
ooi = "new_households_with_ISG_appliance_stat"
def classify(data):
    data = data[ooi]
    data = data[:,60]
    classes = np.zeros(data.shape)
    classes[data>10] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.6)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 90 cases of interest
# [INFO/MainProcess] mean: 0.66, mass: 0.05, coverage: 0.366666666667, density: 0.66 restricted_dimensions: 18

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(33)
box1.inspect(5)
# Out:
# box        mean      mass  coverage   density   res dim
# 33         0.54     0.063      0.38      0.54        17
#
# uncertainty                                              box 33
#                                                         min       max    qp values
# division_effect_media                                     9 -      11     3.95e-08
# memory                                                    2 -       5     3.51e-02
# introduction_phase                                        7 -      30     3.92e-02
# A_S_L_preferred_information_source_early_majority_3    0.28 -    0.55     1.72e-01
# Interaction_1_multiplicator                            0.62 -    1.50     2.00e-01
# change_threshold_to_reach_for_weights_2                0.61 -    3.54     2.05e-01
# Interaction_3_multiplicator                            0.56 -    1.50     2.68e-01
# social_value_difference_to_mean                        0.43 -    1.00     3.07e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.18     3.07e-01
# Interaction_5_multiplicator                            0.50 -    1.44     3.49e-01
# minimum_percentage_for_no_rejection                    0.04 -    0.20     3.49e-01
# A_S_L_preferred_information_source_early_majority_2    0.15 -    0.44     3.49e-01
# A_S_L_preferred_information_source_early_adopter_1     0.26 -    0.55     3.50e-01
# A_S_L_preferred_information_source_laggard_3           0.01 -    0.20     3.50e-01
# Increase_in_memory_for_late_categories                    1 -      20     3.97e-01
# growth_phase                                              9 -      72     3.97e-01
# Number_of_month_before_decision_rejection                37 -      84     5.52e-01
#
#
# box        mean      mass  coverage   density   res dim
# 5          0.15      0.53      0.91      0.15         4
#
# uncertainty                                   box 5
#                                             min       max    qp values
# division_effect_media                         6 -      12     5.20e-03
# memory                                        2 -       5     3.86e-02
# introduction_phase                            6 -      34     2.66e-01
# change_threshold_to_reach_for_weights_2    0.50 -    3.82     3.07e-01

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage     density   mass        mean res dim
# 0           1       0.072      1       0.072       0
# 1           1  0.07700535  0.935  0.07700535       1
# 2           1  0.08266361  0.871  0.08266361       1
# 3           1  0.08933002  0.806  0.08933002       1
# 4           1  0.09703504  0.742  0.09703504       1
# 5           1   0.1063516  0.677   0.1063516       1
# 6           1   0.1174551  0.613   0.1174551       1
# 7           1   0.1237113  0.582   0.1237113       2
# 8           1   0.1304348  0.552   0.1304348       3
# 9           1   0.1374046  0.524   0.1374046       4
# 10  0.9722222   0.1498929  0.467   0.1498929       5
# 11  0.9722222   0.1715686  0.408   0.1715686       5
# 12  0.9027778   0.2090032  0.311   0.2090032       6
# 13  0.9027778    0.220339  0.295    0.220339       7
# 14      0.875   0.2480315  0.254   0.2480315       7
# 15  0.8611111   0.2594142  0.239   0.2594142       7
# 16  0.8611111    0.283105  0.219    0.283105       7
# 17  0.8611111   0.3054187  0.203   0.3054187       7
# 18  0.8055556   0.3473054  0.167   0.3473054       7
# 19  0.7916667   0.3607595  0.158   0.3607595       7
# 20  0.7916667        0.38   0.15        0.38       8
# 21  0.7916667   0.4014085  0.142   0.4014085       9
# 22  0.7777778   0.4242424  0.132   0.4242424       9
# 23  0.7777778   0.4590164  0.122   0.4590164       9
# 24  0.7638889   0.4782609  0.115   0.4782609       9
# 25       0.75   0.4954128  0.109   0.4954128       9
# 26  0.7361111   0.5145631  0.103   0.5145631       9
# 27  0.7222222   0.5360825  0.097   0.5360825      10
# 28  0.7222222   0.5652174  0.092   0.5652174      11
# 29  0.7222222   0.5977011  0.087   0.5977011      12
# 30  0.7083333   0.6219512  0.082   0.6219512      12
# 31  0.6944444   0.6493506  0.077   0.6493506      13
# 32  0.6805556   0.6712329  0.073   0.6712329      14
# 33  0.6666667   0.6956522  0.069   0.6956522      15
# 34  0.6527778   0.7230769  0.065   0.7230769      16
# 35  0.6111111   0.7586207  0.058   0.7586207      16
# 36  0.5972222   0.7818182  0.055   0.7818182      16
# 37  0.5833333   0.8076923  0.052   0.8076923      17
# 38  0.5694444        0.82   0.05        0.82      18
# 39  0.5833333   0.8235294  0.051   0.8235294      18
# 40  0.5972222   0.8269231  0.052   0.8269231      18
#
# [41 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
