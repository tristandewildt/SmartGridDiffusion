# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/80 runs.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 80
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines

results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'percentage_of_early_adopters_with_ISG_appliances':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_adopters_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 51.25

# %%
ooi = "percentage_of_early_adopters_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data>40] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 80 points remaining, containing 36 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.05, coverage: 0.111111111111, density: 1.0 restricted_dimensions: 9

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density    mass       mean res dim
# 0           1       0.45       1       0.45       0
# 1           1  0.4736842    0.95  0.4736842       1
# 2           1        0.5     0.9        0.5       2
# 3           1  0.5294118    0.85  0.5294118       3
# 4           1     0.5625     0.8     0.5625       4
# 5   0.9166667  0.6346154    0.65  0.6346154       5
# 6   0.9166667  0.6734694  0.6125  0.6734694       6
# 7   0.8888889  0.6956522   0.575  0.6956522       6
# 8   0.8055556  0.7631579   0.475  0.7631579       6
# 9   0.8055556  0.8055556    0.45  0.8055556       7
# 10  0.8055556  0.8529412   0.425  0.8529412       8
# 11  0.8055556  0.8787879  0.4125  0.8787879       9
# 12  0.7777778  0.9032258  0.3875  0.9032258       9
# 13       0.75  0.9310345  0.3625  0.9310345       9
# 14  0.7222222   0.962963  0.3375   0.962963       9
# 15  0.6944444          1  0.3125          1       9
# 16  0.6388889          1  0.2875          1       9
# 17  0.5833333          1  0.2625          1       9
# 18  0.5277778          1  0.2375          1       9
# 19        0.5          1   0.225          1       9
# 20  0.4722222          1  0.2125          1       9
# 21  0.4444444          1     0.2          1       9
# 22  0.4166667          1  0.1875          1       9
# 23  0.3888889          1   0.175          1       9
# 24  0.3611111          1  0.1625          1       9
# 25  0.3333333          1    0.15          1       9
# 26  0.3055556          1  0.1375          1       9
# 27  0.2777778          1   0.125          1       9
# 28       0.25          1  0.1125          1       9
# 29  0.2222222          1     0.1          1       9
# 30  0.1944444          1  0.0875          1       9
# 31  0.1666667          1   0.075          1       9
# 32  0.1388889          1  0.0625          1       9
# 33  0.1111111          1    0.05          1       9
#
# [34 rows x 5 columns]

# %%
box1.inspect(9)
box1.inspect(11)
box1.inspect(15)
# Out:
# box        mean      mass  coverage   density   res dim
# 9          0.81      0.45      0.81      0.81         7
#
# uncertainty                                               box 9
#                                                         min       max    qp values
# memory                                                    3 -       5     2.63e-02
# A_S_L_preferred_information_source_laggard_5           0.21 -    0.39     2.90e-01
# valuation_per_household_encountered_late_majority      0.05 -    0.10     3.55e-01
# change_threshold_to_reach_for_weights_1                0.86 -    7.98     3.55e-01
# A_S_L_preferred_information_source_early_majority_2    0.17 -    0.45     3.55e-01
# social_value_difference_to_mean                        0.74 -    4.98     4.70e-01
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.53     5.99e-01
#
#
# box        mean      mass  coverage   density   res dim
# 11         0.88      0.41      0.81      0.88         9
#
# uncertainty                                              box 11
#                                                         min       max    qp values
# memory                                                    3 -       5     6.53e-03
# A_S_L_preferred_information_source_laggard_5           0.21 -    0.39     2.25e-01
# valuation_per_household_encountered_late_majority      0.05 -    0.10     3.10e-01
# Interaction_1_multiplicator                            0.53 -    3.90     3.10e-01
# change_threshold_to_reach_for_weights_1                0.86 -    7.98     3.10e-01
# A_S_L_preferred_information_source_early_majority_2    0.17 -    0.45     3.10e-01
# social_value_difference_to_mean                        0.74 -    4.98     4.54e-01
# Number_of_month_before_decision_rejection                37 -      72     4.54e-01
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.53     6.29e-01
#
#
# box        mean      mass  coverage   density   res dim
# 15            1      0.31      0.69         1         9
#
# uncertainty                                              box 15
#                                                         min       max    qp values
# memory                                                    3 -       5     2.58e-03
# A_S_L_preferred_information_source_laggard_5           0.21 -    0.35     3.55e-02
# valuation_per_household_encountered_late_majority      0.05 -    0.10     1.46e-01
# A_S_L_preferred_information_source_early_majority_2    0.17 -    0.45     1.46e-01
# social_value_difference_to_mean                        1.11 -    4.98     1.57e-01
# change_threshold_to_reach_for_weights_1                0.86 -    7.98     3.75e-01
# A_S_L_preferred_information_source_early_adopter_1     0.28 -    0.53     3.89e-01
# Interaction_1_multiplicator                            0.53 -    3.90     1.00e+00
# Number_of_month_before_decision_rejection                37 -      72     1.00e+00

# %%
prim_obj.show_boxes()
plt.show()
