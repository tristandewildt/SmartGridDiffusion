# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2500_runs_experiment_2.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 250
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis.plotting import envelopes, KDE, lines

results = (experiments, outcomes)

for key, value in outcomes.items():
    if key == 'percentage_of_early_majority_with_ISG_appliances':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_majority_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 92.6

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = data[:,60]
    classes = np.zeros(data.shape)
    classes[data>15] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.4)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 2500 points remaining, containing 24 cases of interest
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-8977aefe42c2> in <module>()
# ----> 1 box1 = prim_obj.find_box()
#
# C:\Users\Titan946\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in find_box(self)
#     807         else:
#     808             # make a dump box
# --> 809             info('box does not meet threshold criteria, value is {}, returning dump box'.format(box.mean[-1]))
#     810             box = PrimBox(self, self.box_init, self.yi_remaining[:])
#     811             self.boxes.append(box)
#
# TypeError: 'float' object has no attribute '__getitem__'

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#       coverage    density    mass       mean res dim
# 0            1     0.7184       1     0.7184       0
# 1    0.9565702  0.7233684    0.95  0.7233684       1
# 2    0.9159243  0.7291667  0.9024  0.7291667       2
# 3    0.8797327  0.7372842  0.8572  0.7372842       2
# 4    0.8541203  0.7403475  0.8288  0.7403475       3
# 5    0.8346325  0.7476309   0.802  0.7476309       3
# 6    0.8134744  0.7534812  0.7756  0.7534812       3
# 7    0.7912027  0.7558511   0.752  0.7558511       4
# 8    0.7555679  0.7597984  0.7144  0.7597984       5
# 9    0.7227171  0.7653302  0.6784  0.7653302       6
# 10   0.6904232  0.7697083  0.6444  0.7697083       6
# 11   0.6592428  0.7738562   0.612  0.7738562       7
# 12   0.6297327  0.7783895  0.5812  0.7783895       8
# 13   0.6024499   0.784058   0.552   0.784058       9
# 14   0.5757238  0.7887109  0.5244  0.7887109      10
# 15   0.5495546  0.7927711   0.498  0.7927711      11
# 16   0.5250557  0.7978003  0.4728  0.7978003      12
# 17   0.5072383  0.8005272  0.4552  0.8005272      13
# 18   0.4844098  0.8048104  0.4324  0.8048104      14
# 19   0.4626949  0.8099415  0.4104  0.8099415      15
# 20   0.4420935  0.8151951  0.3896  0.8151951      16
# 21    0.419265  0.8202614  0.3672  0.8202614      16
# 22   0.3780624  0.8310894  0.3268  0.8310894      17
# 23   0.3680401  0.8335435  0.3172  0.8335435      17
# 24   0.3513363  0.8379814  0.3012  0.8379814      18
# 25   0.3351893   0.841958   0.286   0.841958      19
# 26   0.3207127  0.8483063  0.2716  0.8483063      20
# 27   0.3062361  0.8527132   0.258  0.8527132      21
# 28   0.2973274  0.8557692  0.2496  0.8557692      21
# 29   0.2839644  0.8614865  0.2368  0.8614865      22
# 30   0.2711581   0.866548  0.2248   0.866548      23
# 31   0.2583519  0.8705441  0.2132  0.8705441      23
# 32   0.2461024  0.8735178  0.2024  0.8735178      23
# 33   0.2344098  0.8770833   0.192  0.8770833      23
# 34   0.2065702  0.8833333   0.168  0.8833333      24
# 35   0.1948775  0.8883249  0.1576  0.8883249      25
# 36   0.1859688  0.8930481  0.1496  0.8930481      25
# 37   0.1753898  0.8974359  0.1404  0.8974359      25
# 38   0.1670379  0.9009009  0.1332  0.9009009      25
# 39   0.1603563  0.9113924  0.1264  0.9113924      25
# 40    0.153118  0.9166667    0.12  0.9166667      26
# 41   0.1464365   0.922807   0.114   0.922807      27
# 42   0.1341871  0.9305019  0.1036  0.9305019      27
# 43   0.1314031  0.9328063  0.1012  0.9328063      27
# 44   0.1247216  0.9411765  0.0952  0.9411765      27
# 45   0.1191537  0.9469027  0.0904  0.9469027      27
# 46   0.1135857   0.953271  0.0856   0.953271      27
# 47   0.1085746  0.9605911  0.0812  0.9605911      27
# 48   0.1035635    0.96875  0.0768    0.96875      27
# 49  0.09855234  0.9725275  0.0728  0.9725275      27
# 50   0.0935412  0.9767442  0.0688  0.9767442      27
# 51  0.08908686  0.9815951  0.0652  0.9815951      27
# 52  0.08463252   0.987013  0.0616   0.987013      27
# 53  0.08073497  0.9931507  0.0584  0.9931507      27
# 54  0.07683742          1  0.0552          1      27
# 55  0.07293987          1  0.0524          1      27
# 56  0.07349666          1  0.0528          1      27
# 57  0.07405345          1  0.0532          1      27
# 58  0.07461024          1  0.0536          1      27
# 59  0.07516704          1   0.054          1      27
#            ...        ...     ...        ...     ...
#
# [69 rows x 5 columns]

# %%
box1.inspect(9)
box1.inspect(10)
# Out:
# box        mean      mass  coverage   density   res dim
# 9          0.77      0.68      0.72      0.77         6
#
# uncertainty                                               box 9
#                                                         min       max    qp values
# introduction_phase                                        9 -      36     5.49e-02
# difference_between_peak_and_offpeak_price              0.05 -    0.23     1.02e-01
# Interaction_5_multiplicator                            0.55 -    1.50     2.58e-01
# Degree_of_correlation_with_previous_data               0.20 -    0.77     3.08e-01
# A_S_L_preferred_information_source_early_majority_2    0.15 -    0.44     3.18e-01
# growth_phase                                              7 -      36     4.14e-01
#
#
# box        mean      mass  coverage   density   res dim
# 10         0.77      0.64      0.69      0.77         6
#
# uncertainty                                              box 10
#                                                         min       max    qp values
# introduction_phase                                        9 -      36     4.91e-02
# difference_between_peak_and_offpeak_price              0.05 -    0.23     8.94e-02
# Degree_of_correlation_with_previous_data               0.23 -    0.77     1.84e-01
# Interaction_5_multiplicator                            0.55 -    1.50     2.55e-01
# A_S_L_preferred_information_source_early_majority_2    0.15 -    0.44     3.31e-01
# growth_phase                                              7 -      36     3.98e-01

# %%
prim_obj.show_boxes()
plt.show()
