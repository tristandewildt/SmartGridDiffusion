# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/100_runs_bounded_with_decrease.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 30
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_households_owning_ISG_app"
ooi = outcomes[ooi_name]
ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
temp_outcomes = {ooi_name: ooi}
print ooi.shape

lines((experiments, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()
# Out:
# (500, 151)

# %%
import scipy as sp
# ooi_name = "percentage_of_households_owning_ISG_app"
# # ooi = outcomes[ooi_name]
# # ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
# # temp_outcomes = {ooi_name: ooi}
# print sp.stats.percentileofscore(outcomes[temp_outcomes][:,-1].ravel(), 25)
# # print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)

# %%
# ooi_name = "percentage_of_households_owning_ISG_app"
# ooi = outcomes[ooi_name]
# ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
# temp_outcomes = {ooi_name: ooi}
# ooi_name = "percentage_of_households_owning_ISG_app"
# ooi = outcomes[ooi_name]
# ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
# temp_outcomes = {ooi_name: ooi}
# print ooi.shape

# %%
# ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<3] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-0c208ff352bb> in <module>()
#       7     return classes
#       8
# ----> 9 prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in __init__(self, results, classify, obj_function, peel_alpha, paste_alpha, mass_min, threshold, threshold_type, incl_unc)
#     630             self.y = results[1][classify]
#     631         elif callable(classify):
# --> 632             self.y = classify(results[1])
#     633         else:
#     634             raise TypeError("unknown type for classify")
#
# <ipython-input-97-0c208ff352bb> in classify(data)
#       1 # ooi = "percentage_of_households_owning_ISG_app"
#       2 def classify(data):
# ----> 3     data = data[temp_outcomes]
#       4     data = data[:,-1]
#       5     classes = np.zeros(data.shape)
#
# TypeError: unhashable type: 'dict'

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 500 points remaining, containing 292 cases of interest
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-8977aefe42c2> in <module>()
# ----> 1 box1 = prim_obj.find_box()
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in find_box(self)
#     780
#     781         #  perform peeling phase
# --> 782         box = self._peel(box)
#     783         debug("peeling completed")
#     784
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in _peel(self, box)
#    1085         mass_old = box.yi.shape[0]/self.n
#    1086
# -> 1087         x = self.x[box.yi]
#    1088
#    1089         #identify all possible peels
#
# C:\Python27\lib\site-packages\numpy\ma\core.pyc in __getitem__(self, indx)
#    2990 #            raise IndexError(msg)
#    2991         _data = ndarray.view(self, ndarray)
# -> 2992         dout = ndarray.__getitem__(_data, indx)
#    2993         # We could directly use ndarray.__getitem__ on self...
#    2994         # But then we would have to modify __array_finalize__ to prevent the
#
# IndexError: index 100 is out of bounds for size 100

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-2d8a4164246d> in <module>()
# ----> 1 box1.show_ppt()
#       2 box1.show_tradeoff()
#       3 plt.show()
#
# NameError: name 'box1' is not defined

# %%
box1.inspect(6)
