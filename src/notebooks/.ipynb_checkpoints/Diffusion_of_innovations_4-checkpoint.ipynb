# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/48 runs.bz2')

# %%
from analysis import prim

# %%
desired__nr_lines = 48
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
results = (experiments, outcomes)
from analysis.plotting import envelopes, KDE, lines
for key, value in outcomes.items():
     if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                      show_envelope=True, experiments_to_show=indices, 
                      titles="")
#         n = key
#         plt.savefig("./pictures/KDE {}.png".format(key), dpi=75)
    
plt.show()

# %%
import scipy as sp
ooi_name = "percentage_of_households_owning_ISG_app"
# # ooi = outcomes[ooi_name]
# # ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))
# # temp_outcomes = {ooi_name: ooi}
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# # print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 58.3333333333

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
        data = data[ooi]
        data = data[:,-1]
        classes = np.zeros(data.shape)
        classes[data>10] = 1
        return classes
    
prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 48 points remaining, containing 32 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.0625, coverage: 0.09375, density: 1.0 restricted_dimensions: 7

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#    coverage    density        mass       mean res dim
# 0         1  0.6666667           1  0.6666667       0
# 1         1  0.7111111      0.9375  0.7111111       1
# 2   0.96875  0.7380952       0.875  0.7380952       1
# 3   0.96875  0.7948718      0.8125  0.7948718       2
# 4   0.96875  0.8378378   0.7708333  0.8378378       3
# 5    0.9375  0.8571429   0.7291667  0.8571429       3
# 6   0.90625  0.8787879      0.6875  0.8787879       4
# 7     0.875  0.9032258   0.6458333  0.9032258       5
# 8   0.84375  0.9310345   0.6041667  0.9310345       6
# 9    0.8125   0.962963      0.5625   0.962963       7
# 10  0.78125          1   0.5208333          1       7
# 11  0.71875          1   0.4791667          1       7
# 12  0.65625          1      0.4375          1       7
# 13  0.59375          1   0.3958333          1       7
# 14   0.5625          1       0.375          1       7
# 15  0.53125          1   0.3541667          1       7
# 16      0.5          1   0.3333333          1       7
# 17  0.46875          1      0.3125          1       7
# 18   0.4375          1   0.2916667          1       7
# 19  0.40625          1   0.2708333          1       7
# 20    0.375          1        0.25          1       7
# 21  0.34375          1   0.2291667          1       7
# 22   0.3125          1   0.2083333          1       7
# 23  0.28125          1      0.1875          1       7
# 24     0.25          1   0.1666667          1       7
# 25  0.21875          1   0.1458333          1       7
# 26   0.1875          1       0.125          1       7
# 27  0.15625          1   0.1041667          1       7
# 28    0.125          1  0.08333333          1       7
# 29  0.09375          1      0.0625          1       7
#
# [30 rows x 5 columns]

# %%
box1.inspect(6)
box1.inspect(11)
box1.inspect(13)
# Out:
# box        mean      mass  coverage   density   res dim
# 6          0.88      0.69      0.91      0.88         4
#
# uncertainty                                               box 6
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_adopter_1     0.29 -    0.54     1.30e-01
# A_S_L_preferred_information_source_early_majority_1    0.01 -    0.19     3.10e-01
# A_S_L_preferred_information_source_innovator_1         0.51 -    0.98     3.10e-01
# A_S_L_Max_difference_in_price_tolerated_1              0.32 -    0.60     4.82e-01
#
#
# box        mean      mass  coverage   density   res dim
# 11            1      0.48      0.72         1         7
#
# uncertainty                                              box 11
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_adopter_1     0.29 -    0.54     5.96e-02
# A_S_L_preferred_information_source_innovator_1         0.51 -    0.98     1.47e-01
# A_S_L_preferred_information_source_early_majority_1    0.01 -    0.19     1.47e-01
# A_S_L_preferred_information_source_early_majority_3    0.28 -    0.54     1.70e-01
# A_S_L_preferred_information_source_early_adopter_2     0.15 -    0.44     3.91e-01
# A_S_L_Max_difference_in_price_tolerated_4              0.00 -    0.14     3.91e-01
# A_S_L_Max_difference_in_price_tolerated_1              0.32 -    0.59     4.20e-01
#
#
# box        mean      mass  coverage   density   res dim
# 13            1       0.4      0.59         1         7
#
# uncertainty                                              box 13
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_adopter_1     0.29 -    0.54     6.17e-02
# A_S_L_preferred_information_source_innovator_1         0.51 -    0.98     1.49e-01
# A_S_L_preferred_information_source_early_majority_1    0.01 -    0.19     1.49e-01
# A_S_L_preferred_information_source_early_majority_3    0.28 -    0.54     1.78e-01
# A_S_L_preferred_information_source_early_adopter_2     0.15 -    0.44     3.96e-01
# A_S_L_Max_difference_in_price_tolerated_4              0.00 -    0.14     3.96e-01
# A_S_L_Max_difference_in_price_tolerated_1              0.32 -    0.55     4.88e-01

# %%
prim_obj.show_boxes()
plt.show()
