# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/200 runs.bz2')

# %%
from analysis import prim

# %%
# desired__nr_lines = 24
# nr_cases = experiments.shape[0]
# indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_early_majority_with_ISG_appliances"
ooi = outcomes[ooi_name]

print ooi.shape

ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))

temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (200L, 8L, 151L)
# (1600L, 151L)

# %%
desired__nr_lines = 200
nr_cases = ooi.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# envelopes((experiments, temp_outcomes),
#           fill=True, density=KDE)

lines((ooi, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_majority_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 96.2350993377

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = np.mean(data,axis=1)
#     print data.shape
    data = data[:,-1]
#     print data.shape
    classes = np.zeros(data.shape)
    classes[data>20] = 1
    return classes

# print outcomes.keys()

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 200 points remaining, containing 29 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.05, coverage: 0.344827586207, density: 1.0 restricted_dimensions: 20.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density   mass      mean  res dim
# 0   1.000000  0.145000  1.000  0.145000        0
# 1   1.000000  0.152632  0.950  0.152632        1
# 2   1.000000  0.161111  0.900  0.161111        1
# 3   1.000000  0.170588  0.850  0.170588        2
# 4   1.000000  0.180124  0.805  0.180124        3
# 5   1.000000  0.190789  0.760  0.190789        4
# 6   1.000000  0.201389  0.720  0.201389        5
# 7   1.000000  0.213235  0.680  0.213235        6
# 8   1.000000  0.224806  0.645  0.224806        7
# 9   1.000000  0.237705  0.610  0.237705        8
# 10  1.000000  0.252174  0.575  0.252174        9
# 11  1.000000  0.266055  0.545  0.266055       10
# 12  1.000000  0.281553  0.515  0.281553       11
# 13  1.000000  0.298969  0.485  0.298969       11
# 14  1.000000  0.315217  0.460  0.315217       11
# 15  1.000000  0.333333  0.435  0.333333       11
# 16  1.000000  0.353659  0.410  0.353659       11
# 17  1.000000  0.376623  0.385  0.376623       11
# 18  1.000000  0.397260  0.365  0.397260       11
# 19  1.000000  0.426471  0.340  0.426471       11
# 20  1.000000  0.453125  0.320  0.453125       11
# 21  1.000000  0.483333  0.300  0.483333       12
# 22  1.000000  0.508772  0.285  0.508772       13
# 23  1.000000  0.537037  0.270  0.537037       14
# 24  0.965517  0.560000  0.250  0.560000       14
# 25  0.931034  0.586957  0.230  0.586957       15
# 26  0.896552  0.604651  0.215  0.604651       15
# 27  0.896552  0.634146  0.205  0.634146       16
# 28  0.862069  0.675676  0.185  0.675676       17
# 29  0.862069  0.714286  0.175  0.714286       18
# 30  0.862069  0.757576  0.165  0.757576       19
# 31  0.827586  0.774194  0.155  0.774194       19
# 32  0.793103  0.793103  0.145  0.793103       19
# 33  0.758621  0.814815  0.135  0.814815       19
# 34  0.724138  0.840000  0.125  0.840000       19
# 35  0.724138  0.913043  0.115  0.913043       20
# 36  0.689655  0.952381  0.105  0.952381       20
# 37  0.655172  1.000000  0.095  1.000000       20
# 38  0.620690  1.000000  0.090  1.000000       20
# 39  0.586207  1.000000  0.085  1.000000       20
# 40  0.551724  1.000000  0.080  1.000000       20
# 41  0.517241  1.000000  0.075  1.000000       20
# 42  0.482759  1.000000  0.070  1.000000       20
# 43  0.448276  1.000000  0.065  1.000000       20
# 44  0.413793  1.000000  0.060  1.000000       20
# 45  0.379310  1.000000  0.055  1.000000       20
# 46  0.344828  1.000000  0.050  1.000000       20

# %%
box1.inspect(32)
box1.inspect(20)
box1.inspect(23)
# Out:
# box        mean      mass  coverage   density   res dim
# 32         0.79      0.14      0.79      0.79        19
#
# uncertainty                                              box 32
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     3.58e-03
# Increase_in_memory_for_late_categories                    6 -      20     5.71e-02
# A_S_L_preferred_information_source_early_adopter_2     0.17 -    0.45     1.06e-01
# A_S_L_preferred_information_source_laggard_4           0.13 -    0.29     1.47e-01
# growth_phase                                              6 -      30     1.59e-01
# valuation_per_household_encountered_late_majority      0.05 -    0.10     1.59e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.19     1.59e-01
# A_S_L_preferred_information_source_late_majority_3     0.15 -    0.43     1.59e-01
# social_value_difference_to_mean                        0.43 -    1.00     2.33e-01
# A_S_L_preferred_information_source_early_majority_3    0.27 -    0.55     2.33e-01
# Lifetime_ISG_appliance                                    8 -      15     2.64e-01
# A_S_L_preferred_information_source_early_adopter_1     0.26 -    0.54     3.34e-01
# introduction_phase                                        8 -      36     3.34e-01
# change_threshold_to_reach_for_weights_2                0.50 -    1.44     3.34e-01
# A_S_L_preferred_information_source_laggard_3           0.01 -    0.20     3.34e-01
# Degree_of_correlation_with_previous_data               0.23 -    0.80     4.64e-01
# Interaction_3_multiplicator                            0.54 -    1.50     4.64e-01
# Interaction_4_multiplicator                            0.50 -    1.42     4.64e-01
# Initial_minimum_amount_savings_bounded_rational        1.09 -    2.99     4.64e-01
#
#
# box        mean      mass  coverage   density   res dim
# 20         0.45      0.32         1      0.45        11
#
# uncertainty                                              box 20
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     6.54e-03
# Increase_in_memory_for_late_categories                    3 -      20     2.43e-01
# A_S_L_preferred_information_source_early_adopter_1     0.26 -    0.54     3.05e-01
# A_S_L_preferred_information_source_early_adopter_2     0.17 -    0.45     3.41e-01
# A_S_L_preferred_information_source_laggard_4           0.10 -    0.29     3.78e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.19     3.78e-01
# A_S_L_preferred_information_source_late_majority_3     0.15 -    0.43     3.78e-01
# Degree_of_correlation_with_previous_data               0.23 -    0.80     4.18e-01
# Interaction_4_multiplicator                            0.50 -    1.42     4.18e-01
# Initial_minimum_amount_savings_bounded_rational        1.09 -    2.99     4.18e-01
# Interaction_3_multiplicator                            0.54 -    1.50     5.04e-01
#
#
# box        mean      mass  coverage   density   res dim
# 23         0.54      0.27         1      0.54        14
#
# uncertainty                                              box 23
#                                                         min       max    qp values
# Learning_rate_appliances_1                             0.94 -    0.97     2.95e-03
# Increase_in_memory_for_late_categories                    3 -      20     1.88e-01
# A_S_L_preferred_information_source_early_adopter_1     0.26 -    0.54     2.57e-01
# A_S_L_preferred_information_source_early_adopter_2     0.17 -    0.45     3.42e-01
# A_S_L_preferred_information_source_laggard_3           0.01 -    0.20     3.42e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.19     3.42e-01
# A_S_L_preferred_information_source_late_majority_3     0.15 -    0.43     3.42e-01
# valuation_per_household_encountered_late_majority      0.05 -    0.10     3.90e-01
# change_threshold_to_reach_for_weights_2                0.50 -    1.44     3.90e-01
# A_S_L_preferred_information_source_laggard_4           0.10 -    0.29     3.90e-01
# Initial_minimum_amount_savings_bounded_rational        1.09 -    2.99     3.90e-01
# Degree_of_correlation_with_previous_data               0.23 -    0.80     4.43e-01
# Interaction_4_multiplicator                            0.50 -    1.42     4.43e-01
# Interaction_3_multiplicator                            0.54 -    1.50     4.98e-01

# %%
prim_obj.show_boxes()
plt.show()
