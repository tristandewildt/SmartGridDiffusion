# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/1000_runs_neoclassical_rational.bz2')

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes
from analysis.plotting_util import KDE

envelopes((experiments, outcomes), outcomes_to_show="percentage_of_households_owning_ISG_app",
          fill=True, density=KDE)
plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# Out:
# 0.0

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<15] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 0 cases of interest
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-8977aefe42c2> in <module>()
# ----> 1 box1 = prim_obj.find_box()
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in find_box(self)
#     774
#     775         # make a new box that contains all the remaining data points
# --> 776         box = PrimBox(self, self.box_init, self.yi_remaining[:])
#     777
#     778         #  perform peeling phase
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in __init__(self, prim, box_lims, indices)
#     323
#     324         # indices van data in box
# --> 325         self.update(box_lims, indices)
#     326
#     327     def __getattr__(self, name):
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in update(self, box_lims, indices)
#     455         coi = self.prim.determine_coi(self.yi)
#     456
# --> 457         data = {'coverage':coi/self.prim.t_coi,
#     458                 'density':coi/y.shape[0],
#     459                 'mean':np.mean(y),
#
# ZeroDivisionError: division by zero

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(22)
box1.inspect(20)

# %%
box1.inspect(box1._cur_box)

# %%
box1.write_ppt_to_stdout()

# %%
prim_obj.show_boxes()
plt.show()
