# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# import matplotlib as mpl

# import mpld3

# from mpld3 import plugins

# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2000 runs.bz2')
results = (experiments, outcomes)

# %%
desired__nr_lines = 30
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes
#from analysis.plotting_util import KDE
from analysis.plotting import lines, KDE, envelopes

# for key, value in outcomes.items():
#      if key == 'percentage_of_households_owning_ISG_app':
#         fig, axes = lines(results, outcomes_to_show=key, density=KDE,
#                   show_envelope=True, experiments_to_show=indices, 
#                   titles="")
for key, value in outcomes.items():
    if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = envelopes(results, outcomes_to_show=key,
           fill=True, density=KDE)


#         n = key
#         plt.savefig("./pictures/KDE {}.png".format(n), dpi=75)
plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_majority_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)

# %%
ooi = "percentage_of_early_majority_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = data[:,-1]
    classes = np.zeros(data.shape)
    classes[data<40] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 500 points remaining, containing 137 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.092, coverage: 0.335766423358, density: 1.0 restricted_dimensions: 9

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(24)
box1.inspect(25)
# Out:
# box        mean      mass  coverage   density   res dim
# 24         0.72      0.28      0.73      0.72         4
#
# uncertainty                                             box 24
#                                                        min       max    qp values
# Learning_rate_appliances_1                            0.96 -    1.00     5.86e-14
# difference_between_day_and_night_price                0.00 -    0.26     3.59e-05
# A_S_L_preferred_information_source_early_adopter_1    0.25 -    0.54     4.26e-01
# Duration_information_complexity_validity                24 -      70     4.46e-01
#
#
# box        mean      mass  coverage   density   res dim
# 25         0.75      0.26      0.72      0.75         4
#
# uncertainty                                             box 25
#                                                        min       max    qp values
# Learning_rate_appliances_1                            0.96 -    1.00     3.50e-14
# difference_between_day_and_night_price                0.00 -    0.25     4.51e-06
# A_S_L_preferred_information_source_early_adopter_1    0.25 -    0.54     4.14e-01
# Duration_information_complexity_validity                24 -      70     4.89e-01

# %%
box1.inspect(box1._cur_box)
# Out:
# box        mean      mass  coverage   density   res dim
# 36            1     0.092      0.34         1         9
#
# uncertainty                                                                     box 36
#                                                                                min       max    qp values
# Learning_rate_appliances_1                                                    0.97 -    1.00     4.03e-15
# difference_between_day_and_night_price                                        0.00 -    0.25     5.62e-08
# change_threshold_to_reach_for_weights_information_savings_only_per_process    0.54 -    1.50     2.52e-02
# A_S_L_Combined_interaction_short_5                                               1 -       2     4.65e-02
# A_S_L_preferred_information_source_early_adopter_1                            0.25 -    0.49     7.94e-02
# Duration_information_complexity_validity                                        24 -      70     3.80e-01
# A_S_L_preferred_information_source_laggard_4                                  0.11 -    0.30     3.87e-01
# electricity_price_night_fix                                                   0.11 -    0.25     3.87e-01
# A_S_L_Unique_interaction_3                                                       5 -       9     4.30e-01

# %%
box1.write_ppt_to_stdout()
# Out:
#      coverage    density   mass       mean res dim
# 0           1      0.274      1      0.274       0
# 1   0.9927007  0.2863158   0.95  0.2863158       1
# 2   0.9854015  0.2993348  0.902  0.2993348       2
# 3   0.9781022  0.3130841  0.856  0.3130841       2
# 4   0.9781022  0.3300493  0.812  0.3300493       2
# 5   0.9635036  0.3428571   0.77  0.3428571       2
# 6   0.9562044  0.3589041   0.73  0.3589041       2
# 7   0.9489051  0.3757225  0.692  0.3757225       2
# 8   0.9416058  0.3932927  0.656  0.3932927       2
# 9   0.9270073  0.4083601  0.622  0.4083601       2
# 10  0.9051095   0.420339   0.59   0.420339       2
# 11  0.8978102  0.4392857   0.56  0.4392857       2
# 12  0.8905109  0.4586466  0.532  0.4586466       2
# 13  0.8905109   0.484127  0.504   0.484127       2
# 14  0.8905109  0.5104603  0.478  0.5104603       2
# 15  0.8905109  0.5374449  0.454  0.5374449       2
# 16  0.8686131  0.5534884   0.43  0.5534884       2
# 17  0.8613139  0.5784314  0.408  0.5784314       2
# 18  0.8394161  0.5958549  0.386  0.5958549       2
# 19  0.8248175  0.6174863  0.366  0.6174863       3
# 20  0.8029197  0.6358382  0.346  0.6358382       3
# 21  0.7810219  0.6564417  0.326  0.6564417       4
# 22  0.7591241  0.6753247  0.308  0.6753247       4
# 23  0.7518248  0.7054795  0.292  0.7054795       4
# 24   0.729927  0.7246377  0.276  0.7246377       4
# 25  0.7153285  0.7480916  0.262  0.7480916       4
# 26  0.7007299  0.7741935  0.248  0.7741935       5
# 27  0.6788321  0.7948718  0.234  0.7948718       5
# 28  0.6569343  0.8108108  0.222  0.8108108       5
# 29  0.6423358  0.8380952   0.21  0.8380952       5
# 30  0.6277372  0.8686869  0.198  0.8686869       5
# 31  0.6131387   0.893617  0.188   0.893617       6
# 32  0.4525547  0.9393939  0.132  0.9393939       7
# 33  0.4306569  0.9516129  0.124  0.9516129       7
# 34  0.4087591  0.9655172  0.116  0.9655172       7
# 35  0.3941606  0.9818182   0.11  0.9818182       8
# 36  0.3357664          1  0.092          1       9
#
# [37 rows x 5 columns]

# %%
prim_obj.show_boxes()
plt.show()
