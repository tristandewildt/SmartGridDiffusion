# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

import mpld3

from mpld3 import plugins

# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/1000_runs_neoclassical_rational.bz2')
results = (experiments, outcomes)

# %%
desired__nr_lines = 20
nr_cases = experiments.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes
#from analysis.plotting_util import KDE
from analysis.plotting import lines, KDE, envelopes

for key, value in outcomes.items():
     if key == 'percentage_of_households_owning_ISG_app':
        fig, axes = lines(results, outcomes_to_show=key, density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")
        n = key
        plt.savefig("./pictures/KDE {}.png".format(n), dpi=75)
        plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,50].ravel(), 25)
# Out:
# 99.0

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,50]
    classes = np.zeros(data.shape)
    classes[data<10] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 1000 points remaining, containing 459 cases of interest
# [INFO/MainProcess] mean: 0.970588235294, mass: 0.068, coverage: 0.143790849673, density: 0.970588235294 restricted_dimensions: 23

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(24)
box1.inspect(22)
# Out:
# box        mean      mass  coverage   density   res dim
# 24         0.62      0.29      0.39      0.62        15
#
# uncertainty                                               box 24
#                                                          min        max    qp values
# A_S_L_preferred_information_source_laggard_2            0.36 -     0.63     8.53e-02
# A_S_L_preferred_information_source_innovator_1          0.25 -     0.52     1.51e-01
# A_S_L_preferred_information_source_early_adopter_1      0.28 -     0.53     1.59e-01
# A_S_L_percentage_of_information_needed_4                0.71 -     0.98     2.18e-01
# A_S_L_preferred_information_source_late_majority_3      0.10 -     0.28     2.25e-01
# division_effect_media                                   6.39 -    13.67     2.31e-01
# A_S_L_preferred_information_source_early_majority_3     0.11 -     0.29     2.38e-01
# A_S_L_preferred_information_source_early_majority_2     0.36 -     0.64     2.58e-01
# Learning_rate_appliances_1                              0.95 -     1.00     2.82e-01
# A_S_L_preferred_information_source_late_majority_4      0.11 -     0.30     3.41e-01
# introduction_phase                                        13 -       36     3.50e-01
# A_S_L_percentage_of_information_needed_3                0.65 -     0.93     3.57e-01
# maturity_phase                                           100 -      288     3.74e-01
# A_S_L_preferred_information_source_late_majority_5      0.21 -     0.40     3.91e-01
# A_S_L_percentage_of_information_needed_2                0.65 -     0.93     4.68e-01
#
#
# box        mean      mass  coverage   density   res dim
# 22         0.61      0.32      0.43      0.61        14
#
# uncertainty                                               box 22
#                                                          min        max    qp values
# A_S_L_preferred_information_source_laggard_2            0.36 -     0.63     7.65e-02
# A_S_L_preferred_information_source_innovator_1          0.25 -     0.52     1.45e-01
# A_S_L_preferred_information_source_early_adopter_1      0.28 -     0.53     1.50e-01
# A_S_L_preferred_information_source_early_majority_3     0.11 -     0.29     2.05e-01
# A_S_L_percentage_of_information_needed_4                0.71 -     0.98     2.12e-01
# division_effect_media                                   6.39 -    13.67     2.62e-01
# A_S_L_preferred_information_source_early_majority_2     0.36 -     0.64     3.17e-01
# A_S_L_preferred_information_source_late_majority_3      0.10 -     0.29     3.20e-01
# Learning_rate_appliances_1                              0.95 -     1.00     3.37e-01
# A_S_L_percentage_of_information_needed_3                0.65 -     0.93     3.50e-01
# A_S_L_preferred_information_source_late_majority_4      0.11 -     0.30     3.50e-01
# introduction_phase                                        13 -       36     3.66e-01
# maturity_phase                                           100 -      288     3.67e-01
# A_S_L_percentage_of_information_needed_2                0.65 -     0.93     4.51e-01

# %%
box1.inspect(box1._cur_box)
# Out:
# box        mean      mass  coverage   density   res dim
# 62         0.97     0.068      0.14      0.97        23
#
# uncertainty                                               box 62
#                                                          min        max    qp values
# Diffusion_information_number_links                         3 -        4     6.57e-06
# A_S_L_percentage_of_information_needed_3                0.66 -     0.90     6.44e-04
# growth_phase                                              12 -       30     9.23e-04
# A_S_L_preferred_information_source_innovator_1          0.27 -     0.52     2.99e-03
# A_S_L_awareness_threshold_2                                4 -        7     4.51e-03
# division_effect_media                                   6.39 -    13.91     1.94e-02
# A_S_L_preferred_information_source_laggard_2            0.36 -     0.63     1.94e-02
# A_S_L_preferred_information_source_early_adopter_2      0.18 -     0.45     3.83e-02
# A_S_L_percentage_of_information_needed_4                0.71 -     0.98     3.83e-02
# A_S_L_preferred_information_source_late_majority_3      0.10 -     0.28     4.11e-02
# A_S_L_preferred_information_source_early_adopter_1      0.26 -     0.53     4.99e-02
# A_S_L_preferred_information_source_early_majority_3     0.11 -     0.28     7.43e-02
# A_S_L_preferred_information_source_late_majority_5      0.23 -     0.40     7.87e-02
# A_S_L_preferred_information_source_late_majority_4      0.11 -     0.30     8.32e-02
# A_S_L_preferred_information_source_late_majority_2      0.35 -     0.62     8.78e-02
# A_S_L_percentage_of_information_needed_5                0.90 -     1.00     1.41e-01
# Learning_rate_appliances_1                              0.95 -     1.00     1.41e-01
# A_S_L_preferred_information_source_early_majority_1     0.02 -     0.20     2.56e-01
# introduction_phase                                        13 -       36     2.56e-01
# maturity_phase                                           100 -      288     4.38e-01
# A_S_L_preferred_information_source_early_majority_2     0.36 -     0.65     6.77e-01
# A_S_L_percentage_of_information_needed_2                0.65 -     0.93     6.77e-01
# A_S_L_preferred_information_source_laggard_5            0.11 -     0.30     6.77e-01

# %%
box1.write_ppt_to_stdout()

# %%
prim_obj.show_boxes()
plt.show()
