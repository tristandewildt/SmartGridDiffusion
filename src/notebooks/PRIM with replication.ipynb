# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/21 runs.bz2')

# %%
from analysis import prim

# %%
# desired__nr_lines = 24
# nr_cases = experiments.shape[0]
# indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_households_owning_ISG_app"
ooi = outcomes[ooi_name]

print ooi.shape

ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))

temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (21L, 8L, 151L)
# (168L, 151L)

# %%
desired__nr_lines = 20
nr_cases = ooi.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# envelopes((experiments, temp_outcomes),
#           fill=True, density=KDE)

lines((ooi, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()
# Out:
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:443: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 73.7251655629

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = np.mean(data,axis=1)
#     print data.shape
    data = data[:,-1]
#     print data.shape
    classes = np.zeros(data.shape)
    classes[data<20] = 1
    return classes

# print outcomes.keys()

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 21 points remaining, containing 10 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.0952380952381, coverage: 0.2, density: 1.0 restricted_dimensions: 5.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density      mass      mean  res dim
# 0        1.0  0.476190  1.000000  0.476190        0
# 1        1.0  0.526316  0.904762  0.526316        1
# 2        1.0  0.588235  0.809524  0.588235        2
# 3        1.0  0.625000  0.761905  0.625000        2
# 4        1.0  0.666667  0.714286  0.666667        2
# 5        1.0  0.714286  0.666667  0.714286        3
# 6        1.0  0.769231  0.619048  0.769231        3
# 7        1.0  0.833333  0.571429  0.833333        4
# 8        1.0  0.909091  0.523810  0.909091        4
# 9        1.0  1.000000  0.476190  1.000000        5
# 10       0.9  1.000000  0.428571  1.000000        5
# 11       0.8  1.000000  0.380952  1.000000        5
# 12       0.7  1.000000  0.333333  1.000000        5
# 13       0.6  1.000000  0.285714  1.000000        5
# 14       0.5  1.000000  0.238095  1.000000        5
# 15       0.4  1.000000  0.190476  1.000000        5
# 16       0.3  1.000000  0.142857  1.000000        5
# 17       0.2  1.000000  0.095238  1.000000        5

# %%
box1.inspect(5)
box1.inspect(9)
box1.inspect(13)
# Out:
# box        mean      mass  coverage   density   res dim
# 5          0.71      0.67         1      0.71         3
#
# uncertainty                                              box 5
#                                                        min       max    qp values
# A_S_L_preferred_information_source_early_adopter_1    0.27 -    0.51     1.78e-01
# A_S_L_preferred_information_source_early_adopter_2    0.16 -    0.43     4.76e-01
# Lifetime_ISG_appliance                                   9 -      16     6.31e-01
#
#
# box        mean      mass  coverage   density   res dim
# 9             1      0.48         1         1         5
#
# uncertainty                                               box 9
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.17     1.62e-01
# A_S_L_preferred_information_source_early_adopter_1     0.27 -    0.51     3.86e-01
# A_S_L_preferred_information_source_early_majority_2    0.16 -    0.39     3.86e-01
# A_S_L_preferred_information_source_early_adopter_2     0.16 -    0.41     1.00e+00
# Lifetime_ISG_appliance                                    9 -      16     1.00e+00
#
#
# box        mean      mass  coverage   density   res dim
# 13            1      0.29       0.6         1         5
#
# uncertainty                                              box 13
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.17     3.97e-01
# A_S_L_preferred_information_source_early_adopter_1     0.27 -    0.38     5.64e-01
# A_S_L_preferred_information_source_early_adopter_2     0.16 -    0.41     1.00e+00
# Lifetime_ISG_appliance                                    9 -      16     1.00e+00
# A_S_L_preferred_information_source_early_majority_2    0.16 -    0.39     1.00e+00

# %%
prim_obj.show_boxes()
plt.show()
