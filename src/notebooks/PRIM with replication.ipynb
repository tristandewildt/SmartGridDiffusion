# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/200 runs.bz2')

# %%
from analysis import prim

# %%
# desired__nr_lines = 24
# nr_cases = experiments.shape[0]
# indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_households_owning_ISG_app"
ooi = outcomes[ooi_name]

print ooi.shape

ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))

temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (200L, 8L, 151L)
# (1600L, 151L)

# %%
desired__nr_lines = 1600
nr_cases = ooi.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# envelopes((experiments, temp_outcomes),
#           fill=True, density=KDE)

lines((ooi, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 96.2897350993

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
#     data = np.mean(data,axis=1)
#     print data.shape
    data = data[:,-1]
#     print data.shape
    classes = np.zeros(data.shape)
    classes[data>10] = 1
    return classes

# print outcomes.keys()

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)
# Out:
# ---------------------------------------------------------------------------
# PrimException                             Traceback (most recent call last)
# <ipython-input-32-712c779af98a> in <module>()
#      12 # print outcomes.keys()
#      13
# ---> 14 prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)
#
# C:\Users\Tristan\Documents\GitHub\EMAworkbench\src\analysis\prim.pyc in __init__(self, results, classify, obj_function, peel_alpha, paste_alpha, mass_min, threshold, threshold_type, incl_unc)
#     635
#     636         if len(self.y.shape) > 1:
# --> 637             raise PrimException("y is not a 1-d array")
#     638
#     639         # store the remainder of the parameters
#
# PrimException: y is not a 1-d array

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 200 points remaining, containing 56 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.05, coverage: 0.178571428571, density: 1.0 restricted_dimensions: 17.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density   mass      mean  res dim
# 0   1.000000  0.280000  1.000  0.280000        0
# 1   1.000000  0.299465  0.935  0.299465        1
# 2   1.000000  0.316384  0.885  0.316384        2
# 3   1.000000  0.333333  0.840  0.333333        2
# 4   1.000000  0.352201  0.795  0.352201        3
# 5   0.946429  0.404580  0.655  0.404580        4
# 6   0.928571  0.419355  0.620  0.419355        5
# 7   0.910714  0.435897  0.585  0.435897        5
# 8   0.892857  0.450450  0.555  0.450450        6
# 9   0.892857  0.476190  0.525  0.476190        7
# 10  0.875000  0.494949  0.495  0.494949        7
# 11  0.875000  0.521277  0.470  0.521277        7
# 12  0.875000  0.550562  0.445  0.550562        8
# 13  0.857143  0.571429  0.420  0.571429        9
# 14  0.839286  0.594937  0.395  0.594937        9
# 15  0.750000  0.677419  0.310  0.677419        9
# 16  0.732143  0.706897  0.290  0.706897       10
# 17  0.714286  0.727273  0.275  0.727273       11
# 18  0.696429  0.750000  0.260  0.750000       12
# 19  0.678571  0.775510  0.245  0.775510       13
# 20  0.660714  0.804348  0.230  0.804348       14
# 21  0.642857  0.837209  0.215  0.837209       14
# 22  0.625000  0.875000  0.200  0.875000       15
# 23  0.589286  0.916667  0.180  0.916667       16
# 24  0.571429  0.941176  0.170  0.941176       16
# 25  0.553571  0.968750  0.160  0.968750       17
# 26  0.535714  1.000000  0.150  1.000000       17
# 27  0.500000  1.000000  0.140  1.000000       17
# 28  0.464286  1.000000  0.130  1.000000       17
# 29  0.428571  1.000000  0.120  1.000000       17
# 30  0.392857  1.000000  0.110  1.000000       17
# 31  0.357143  1.000000  0.100  1.000000       17
# 32  0.339286  1.000000  0.095  1.000000       17
# 33  0.321429  1.000000  0.090  1.000000       17
# 34  0.303571  1.000000  0.085  1.000000       17
# 35  0.285714  1.000000  0.080  1.000000       17
# 36  0.267857  1.000000  0.075  1.000000       17
# 37  0.250000  1.000000  0.070  1.000000       17
# 38  0.232143  1.000000  0.065  1.000000       17
# 39  0.214286  1.000000  0.060  1.000000       17
# 40  0.196429  1.000000  0.055  1.000000       17
# 41  0.178571  1.000000  0.050  1.000000       17

# %%
box1.inspect(16)
# Out:
# box        mean      mass  coverage   density   res dim
# 16         0.71      0.29      0.73      0.71        10
#
# uncertainty                                              box 16
#                                                         min       max    qp values
# memory                                                    1 -       3     8.34e-04
# change_threshold_to_reach_for_weights_2                0.50 -    1.32     3.48e-02
# A_S_L_preferred_information_source_laggard_3           0.02 -    0.20     9.41e-02
# introduction_phase                                        6 -      34     1.35e-01
# A_S_L_preferred_information_source_laggard_4           0.12 -    0.30     2.44e-01
# Interaction_4_multiplicator                            0.50 -    1.45     2.72e-01
# A_S_L_preferred_information_source_late_majority_3     0.17 -    0.45     2.72e-01
# A_S_L_preferred_information_source_early_majority_3    0.25 -    0.54     3.01e-01
# change_threshold_to_reach_for_weights_3                0.55 -    1.45     3.35e-01
# minimum_percentage_for_no_rejection                    0.03 -    0.20     4.84e-01

# %%
prim_obj.show_boxes()
plt.show()
