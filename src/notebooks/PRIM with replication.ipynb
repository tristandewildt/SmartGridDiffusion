# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/200_runs_experiment_4_with_replication_new.bz2')

# %%
from analysis import prim

# %%
# desired__nr_lines = 24
# nr_cases = experiments.shape[0]
# indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_early_majority_with_ISG_appliances"
ooi = outcomes[ooi_name]

print ooi.shape

ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))

temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (200L, 8L, 151L)
# (1600L, 151L)

# %%
desired__nr_lines = 200
nr_cases = ooi.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# envelopes((experiments, temp_outcomes),
#           fill=True, density=KDE)

lines((ooi, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 86.5976821192

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = np.mean(data,axis=1)
#     print data.shape
    data = data[:,100]
#     print data.shape
    classes = np.zeros(data.shape)
    classes[data>60] = 1
    return classes

# print outcomes.keys()

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 200 points remaining, containing 15 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.05, coverage: 0.666666666667, density: 1.0 restricted_dimensions: 15.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density   mass      mean  res dim
# 0   1.000000  0.075000  1.000  0.075000        0
# 1   1.000000  0.080214  0.935  0.080214        1
# 2   1.000000  0.086207  0.870  0.086207        1
# 3   1.000000  0.093168  0.805  0.093168        1
# 4   1.000000  0.100671  0.745  0.100671        1
# 5   1.000000  0.111111  0.675  0.111111        1
# 6   1.000000  0.121951  0.615  0.121951        1
# 7   1.000000  0.131579  0.570  0.131579        2
# 8   1.000000  0.138889  0.540  0.138889        3
# 9   1.000000  0.147059  0.510  0.147059        4
# 10  1.000000  0.156250  0.480  0.156250        5
# 11  1.000000  0.164835  0.455  0.164835        5
# 12  1.000000  0.174419  0.430  0.174419        5
# 13  1.000000  0.185185  0.405  0.185185        5
# 14  1.000000  0.197368  0.380  0.197368        6
# 15  1.000000  0.208333  0.360  0.208333        6
# 16  1.000000  0.220588  0.340  0.220588        6
# 17  1.000000  0.234375  0.320  0.234375        6
# 18  1.000000  0.250000  0.300  0.250000        6
# 19  1.000000  0.263158  0.285  0.263158        6
# 20  1.000000  0.277778  0.270  0.277778        7
# 21  1.000000  0.294118  0.255  0.294118        8
# 22  1.000000  0.312500  0.240  0.312500        8
# 23  1.000000  0.333333  0.225  0.333333        9
# 24  1.000000  0.357143  0.210  0.357143        9
# 25  1.000000  0.384615  0.195  0.384615        9
# 26  1.000000  0.405405  0.185  0.405405        9
# 27  1.000000  0.428571  0.175  0.428571       10
# 28  1.000000  0.454545  0.165  0.454545       10
# 29  1.000000  0.483871  0.155  0.483871       11
# 30  1.000000  0.517241  0.145  0.517241       11
# 31  1.000000  0.555556  0.135  0.555556       12
# 32  1.000000  0.600000  0.125  0.600000       12
# 33  1.000000  0.652174  0.115  0.652174       12
# 34  1.000000  0.714286  0.105  0.714286       13
# 35  1.000000  0.789474  0.095  0.789474       13
# 36  1.000000  0.833333  0.090  0.833333       13
# 37  1.000000  0.882353  0.085  0.882353       13
# 38  1.000000  0.937500  0.080  0.937500       14
# 39  1.000000  1.000000  0.075  1.000000       15
# 40  0.933333  1.000000  0.070  1.000000       15
# 41  0.866667  1.000000  0.065  1.000000       15
# 42  0.800000  1.000000  0.060  1.000000       15
# 43  0.733333  1.000000  0.055  1.000000       15
# 44  0.666667  1.000000  0.050  1.000000       15

# %%
box1.inspect(12)
box1.inspect(34)
box1.inspect(39)
# Out:
# box        mean      mass  coverage   density   res dim
# 12         0.17      0.43         1      0.17         5
#
# uncertainty                                              box 12
#                                                         min       max    qp values
# growth_phase                                              6 -      24     4.87e-02
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.18     3.49e-01
# Number_of_month_before_decision_rejection                12 -      55     3.81e-01
# A_S_L_preferred_information_source_early_adopter_2     0.18 -    0.45     3.81e-01
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.53     4.87e-01
#
#
# box        mean      mass  coverage   density   res dim
# 34         0.71       0.1         1      0.71        13
#
# uncertainty                                              box 34
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_majority_2    0.22 -    0.42     1.47e-02
# growth_phase                                              6 -      24     2.03e-02
# Number_of_month_before_decision_rejection                12 -      53     1.05e-01
# A_S_L_preferred_information_source_late_majority_1     0.00 -    0.07     1.05e-01
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.18     2.00e-01
# Degree_of_correlation_with_previous_data               0.25 -    0.80     2.72e-01
# A_S_L_preferred_information_source_laggard_3           0.01 -    0.19     2.72e-01
# A_S_L_preferred_information_source_late_majority_2     0.00 -    0.09     2.72e-01
# A_S_L_preferred_information_source_early_adopter_2     0.18 -    0.45     3.65e-01
# Interaction_2_multiplicator                            0.66 -    1.50     3.65e-01
# Learning_rate_appliances_1                             0.94 -    0.98     3.65e-01
# A_S_L_preferred_information_source_early_majority_3    0.25 -    0.53     3.65e-01
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.53     4.78e-01
#
#
# box        mean      mass  coverage   density   res dim
# 39            1     0.075         1         1        15
#
# uncertainty                                              box 39
#                                                         min       max    qp values
# A_S_L_preferred_information_source_early_majority_2    0.22 -    0.42     3.20e-03
# growth_phase                                              6 -      24     1.34e-02
# Learning_rate_appliances_1                             0.94 -    0.97     2.88e-02
# A_S_L_preferred_information_source_laggard_3           0.01 -    0.19     6.49e-02
# A_S_L_preferred_information_source_early_majority_1    0.00 -    0.18     6.49e-02
# A_S_L_preferred_information_source_late_majority_1     0.00 -    0.07     6.49e-02
# A_S_L_preferred_information_source_early_adopter_2     0.18 -    0.45     1.53e-01
# Degree_of_correlation_with_previous_data               0.25 -    0.80     1.53e-01
# Number_of_month_before_decision_rejection                12 -      53     1.53e-01
# A_S_L_preferred_information_source_late_majority_2     0.00 -    0.09     1.53e-01
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.53     3.80e-01
# Interaction_1_multiplicator                            0.50 -    1.37     3.80e-01
# change_threshold_to_reach_for_weights_2                0.51 -    0.80     3.80e-01
# Interaction_2_multiplicator                            0.66 -    1.50     1.00e+00
# A_S_L_preferred_information_source_early_majority_3    0.25 -    0.53     1.00e+00

# %%
prim_obj.show_boxes()
plt.show()
