# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/200 runs.bz2')

# %%
from analysis import prim

# %%
# desired__nr_lines = 24
# nr_cases = experiments.shape[0]
# indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

ooi_name = "percentage_of_early_adopters_with_ISG_appliances"
ooi = outcomes[ooi_name]

print ooi.shape

ooi = np.reshape(ooi, (ooi.shape[0]*ooi.shape[1], ooi.shape[2]))

temp_outcomes = {ooi_name: ooi}

print ooi.shape
# Out:
# (200L, 8L, 151L)
# (1600L, 151L)

# %%
desired__nr_lines = 200
nr_cases = ooi.shape[0]
indices = np.arange(0, nr_cases, nr_cases/desired__nr_lines)

# %%
# envelopes((experiments, temp_outcomes),
#           fill=True, density=KDE)

lines((ooi, temp_outcomes), density=KDE,
                  show_envelope=True, experiments_to_show=indices, 
                  titles="")

plt.show()

# %%
import scipy as sp
ooi = "percentage_of_early_adopters_with_ISG_appliances"
print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
# print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 57.0380794702

# %%
ooi = "percentage_of_early_adopters_with_ISG_appliances"
def classify(data):
    data = data[ooi]
    data = np.mean(data,axis=1)
#     print data.shape
    data = data[:,-1]
#     print data.shape
    classes = np.zeros(data.shape)
    classes[data<20] = 1
    return classes

# print outcomes.keys()

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 200 points remaining, containing 71 cases of interest
# [INFO/MainProcess] mean: 1.0, mass: 0.05, coverage: 0.140845070423, density: 1.0 restricted_dimensions: 10.0

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.write_ppt_to_stdout()
# Out:
#     coverage   density   mass      mean  res dim
# 0   1.000000  0.355000  1.000  0.355000        0
# 1   1.000000  0.373684  0.950  0.373684        1
# 2   1.000000  0.394444  0.900  0.394444        2
# 3   1.000000  0.415205  0.855  0.415205        2
# 4   1.000000  0.438272  0.810  0.438272        2
# 5   1.000000  0.464052  0.765  0.464052        2
# 6   1.000000  0.489655  0.725  0.489655        2
# 7   1.000000  0.518248  0.685  0.518248        3
# 8   1.000000  0.546154  0.650  0.546154        3
# 9   1.000000  0.577236  0.615  0.577236        3
# 10  0.985915  0.603448  0.580  0.603448        3
# 11  0.971831  0.627273  0.550  0.627273        3
# 12  0.957746  0.653846  0.520  0.653846        3
# 13  0.943662  0.683673  0.490  0.683673        4
# 14  0.929577  0.709677  0.465  0.709677        4
# 15  0.915493  0.738636  0.440  0.738636        4
# 16  0.887324  0.759036  0.415  0.759036        4
# 17  0.859155  0.782051  0.390  0.782051        5
# 18  0.830986  0.797297  0.370  0.797297        5
# 19  0.802817  0.814286  0.350  0.814286        5
# 20  0.774648  0.833333  0.330  0.833333        6
# 21  0.746479  0.854839  0.310  0.854839        7
# 22  0.718310  0.864407  0.295  0.864407        8
# 23  0.704225  0.877193  0.285  0.877193        9
# 24  0.676056  0.888889  0.270  0.888889        9
# 25  0.647887  0.901961  0.255  0.901961        9
# 26  0.619718  0.916667  0.240  0.916667        9
# 27  0.591549  0.933333  0.225  0.933333        9
# 28  0.563380  0.952381  0.210  0.952381        9
# 29  0.535211  0.974359  0.195  0.974359        9
# 30  0.521127  1.000000  0.185  1.000000       10
# 31  0.492958  1.000000  0.175  1.000000       10
# 32  0.464789  1.000000  0.165  1.000000       10
# 33  0.436620  1.000000  0.155  1.000000       10
# 34  0.408451  1.000000  0.145  1.000000       10
# 35  0.380282  1.000000  0.135  1.000000       10
# 36  0.352113  1.000000  0.125  1.000000       10
# 37  0.323944  1.000000  0.115  1.000000       10
# 38  0.295775  1.000000  0.105  1.000000       10
# 39  0.267606  1.000000  0.095  1.000000       10
# 40  0.253521  1.000000  0.090  1.000000       10
# 41  0.239437  1.000000  0.085  1.000000       10
# 42  0.225352  1.000000  0.080  1.000000       10
# 43  0.211268  1.000000  0.075  1.000000       10
# 44  0.197183  1.000000  0.070  1.000000       10
# 45  0.183099  1.000000  0.065  1.000000       10
# 46  0.169014  1.000000  0.060  1.000000       10
# 47  0.154930  1.000000  0.055  1.000000       10
# 48  0.140845  1.000000  0.050  1.000000       10

# %%
box1.inspect(19)
box1.inspect(20)
box1.inspect(23)
# Out:
# box        mean      mass  coverage   density   res dim
# 19         0.81      0.35       0.8      0.81         5
#
# uncertainty                                             box 19
#                                                        min       max    qp values
# change_threshold_to_reach_for_weights_2               0.82 -    1.50     1.62e-06
# social_value_difference_to_mean                       0.40 -    0.84     1.56e-04
# Interaction_2_multiplicator                           0.50 -    1.35     9.96e-02
# A_S_L_preferred_information_source_early_adopter_1    0.25 -    0.52     1.95e-01
# Initial_minimum_amount_savings_bounded_rational       1.01 -    2.86     2.47e-01
#
#
# box        mean      mass  coverage   density   res dim
# 20         0.83      0.33      0.77      0.83         6
#
# uncertainty                                              box 20
#                                                         min       max    qp values
# change_threshold_to_reach_for_weights_2                0.82 -    1.50     2.20e-06
# social_value_difference_to_mean                        0.40 -    0.84     2.08e-04
# Interaction_2_multiplicator                            0.50 -    1.35     8.19e-02
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.52     1.75e-01
# Initial_minimum_amount_savings_bounded_rational        1.01 -    2.86     2.23e-01
# A_S_L_preferred_information_source_early_majority_2    0.15 -    0.43     4.18e-01
#
#
# box        mean      mass  coverage   density   res dim
# 23         0.88      0.28       0.7      0.88         9
#
# uncertainty                                              box 23
#                                                         min       max    qp values
# change_threshold_to_reach_for_weights_2                0.82 -    1.50     6.86e-07
# social_value_difference_to_mean                        0.40 -    0.84     9.00e-05
# Initial_minimum_amount_savings_bounded_rational        1.01 -    2.86     9.57e-02
# A_S_L_preferred_information_source_early_adopter_1     0.25 -    0.52     1.01e-01
# Interaction_2_multiplicator                            0.50 -    1.35     1.31e-01
# A_S_L_preferred_information_source_early_majority_3    0.25 -    0.53     2.62e-01
# A_S_L_preferred_information_source_early_majority_2    0.15 -    0.43     2.62e-01
# introduction_phase                                        7 -      36     3.50e-01
# Increase_in_memory_for_late_categories                    1 -      20     3.68e-01

# %%
prim_obj.show_boxes()
plt.show()
