# %%
from expWorkbench import ema_logging, load_results

ema_logging.log_to_stderr(level=ema_logging.INFO)

#load the data
experiments, outcomes = load_results(r'./Data/2000 runs.bz2')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b4ce6d3e6132> in <module>()
# ----> 1 from expWorkbench import ema_logging, load_results
#       2
#       3 ema_logging.log_to_stderr(level=ema_logging.INFO)
#       4
#       5 #load the data
#
# C:\Users\Titan946\Documents\GitHub\EMAworkbench\src\expWorkbench\__init__.py in <module>()
#       2 from ema_logging import *
#       3 from model import *
# ----> 4 from model_ensemble import *
#       5 from outcomes import *
#       6 from uncertainties import *
#
# C:\Users\Titan946\Documents\GitHub\EMAworkbench\src\expWorkbench\model_ensemble.py in <module>()
#      10
#      11
# ---> 12 from deap import base
#      13 from deap import creator
#      14 from deap import tools
#
# ImportError: No module named deap

# %%
from analysis import prim

# %%
# def classify(data):
#     data = data["number_of_households_owning_ISG_app"]

from analysis.plotting import envelopes, KDE, lines
#from analysis.plotting_util import VIOLIN

envelopes((experiments, outcomes), outcomes_to_show="percentage_of_households_owning_ISG_app",
          fill=True, density=KDE)
plt.show()

# %%
import scipy as sp
ooi = "percentage_of_households_owning_ISG_app"
#print sp.stats.percentileofscore(outcomes[ooi][:,-1].ravel(), 25)
print sp.stats.percentileofscore(outcomes[ooi][:,299].ravel(), 25)
# Out:
# 39.3

# %%
envelopes((experiments, outcomes), outcomes_to_show=data,
          fill=True, density=KDE)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f7ce7e2a5432> in <module>()
# ----> 1 envelopes((experiments, outcomes), outcomes_to_show=data,
#       2           fill=True, density=KDE)
#       3 plt.show()
#
# NameError: name 'data' is not defined

# %%
ooi = "percentage_of_households_owning_ISG_app"
def classify(data):
    data = data[ooi]
    data = data[:,299]
    classes = np.zeros(data.shape)
    classes[data>20] = 1
    return classes

prim_obj = prim.Prim((experiments, outcomes), classify, threshold=0.8)

# %%
box1 = prim_obj.find_box()
# Out:
# [INFO/MainProcess] 2000 points remaining, containing 1114 cases of interest
# [INFO/MainProcess] mean: 0.96992481203, mass: 0.0665, coverage: 0.115798922801, density: 0.96992481203 restricted_dimensions: 30

# %%
box1.show_ppt()
box1.show_tradeoff()
plt.show()

# %%
box1.inspect(6)
# Out:
# box        mean      mass  coverage   density   res dim
# 6          0.59      0.73      0.78      0.59         6
#
# uncertainty                                              box 6
#                                                        min       max    qp values
# A_S_L_preferred_information_source_laggard_5          0.11 -    0.30     2.38e-01
# A_S_L_preferred_information_source_laggard_3          0.11 -    0.30     2.78e-01
# A_S_L_valuation_of_savings_bounded_rational_4         0.66 -    0.95     3.03e-01
# A_S_L_preferred_information_source_late_majority_5    0.21 -    0.40     3.16e-01
# A_S_L_preferred_information_source_laggard_2          0.35 -    0.63     3.31e-01
# Probability_of_failure_list_3                         0.00 -    0.01     3.34e-01
